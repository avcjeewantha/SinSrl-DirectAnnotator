# %%
import pandas as pd
# Import PyDrive and associated libraries.
# This only needs to be done once per notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Download a file based on its file ID.
#
# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
file_id = '1wb2d8XT57hZ-*******osawqADSX7Gs'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('mannualData'+'.csv')  
mannualData = pd.read_csv('mannualData'+'.csv')

# %%
x = [[ "එය B-ARG1" , "සංකීර්ණ B-ARG2" , "වන B-be.01" , "අතර O" , "එය O" , "යුක්ති O" , "සහගත O" , "නොවේ O" , ". O" ],[ "එය B-ARG1" , "සංකීර්ණ B-complicate.01" , "වන O" , "අතර O" , "එය O" , "යුක්ති O" , "සහගත O" , "නොවේ O" , ". O" ],[ "එය O" , "සංකීර්ණ O" , "වන O" , "අතර O" , "එය B-ARG1" , "යුක්ති B-justify.01" , "සහගත I-justify.01" , "නොවේ B-ARGM-NEG" , ". O" ]]
y = [[ "එය B-ARG1" , "සංකීර්ණ B-ARG8" , "වන B-be.01" , "අතර O" , "එය O" , "යුක්ති O" , "සහගත O" , "නොවේ O" , ". O" ],[ "එය B-ARG1" , "සංකීර්ණ B-complicate.01" , "වන O" , "අතර O" , "එය O" , "යුක්ති O" , "සහගත O" , "නොවේ O" , ". O" ]]

def makeLists (mannualData = x, predictedData = y):
  noOfPredsInMannualDta = len(mannualData)
  noOfPredsInPredictedDta = len(predictedData)
  newMannualData = []
  for i in range(0, noOfPredsInMannualDta):
    mannualSeq = mannualData[i] #[ "එය B-ARG1" , "සංකීර්ණ B-ARG2" , "වන B-be.01" , "අතර O" , "එය O" , "යුක්ති O" , "සහගත O" , "නොවේ O" , ". O" ]
    newMannualSeq = [] #[ ["එය","B-ARG1"] , ["සංකීර්ණ","B-ARG2"] , ["වන","B-be.01"] , ["අතර","O"] , ["එය","O"] , ["යුක්ති","O"] , ["සහගත","O"] , ["නොවේ","O"] , [".","O"] ]
    for j in mannualSeq:
      a = j.strip()
      newMannualSeq.append(a.split())
    newMannualData.append(newMannualSeq)

  newPredictedData = []
  for i in range(0, noOfPredsInPredictedDta):
    predictedSeq = predictedData[i] #[ "එය B-ARG1" , "සංකීර්ණ B-ARG2" , "වන B-be.01" , "අතර O" , "එය O" , "යුක්ති O" , "සහගත O" , "නොවේ O" , ". O" ]
    newPredictedSeq = [] #[ ["එය","B-ARG1"] , ["සංකීර්ණ","B-ARG2"] , ["වන","B-be.01"] , ["අතර","O"] , ["එය","O"] , ["යුක්ති","O"] , ["සහගත","O"] , ["නොවේ","O"] , [".","O"] ]
    for j in predictedSeq:
      a = j.strip()
      newPredictedSeq.append(a.split())
    newPredictedData.append(newPredictedSeq)
  return newMannualData, newPredictedData

# %%
a = makeLists()
print(a[0])
print(a[1])
# Out:
# [[['එය', 'B-ARG1'], ['සංකීර්ණ', 'B-ARG2'], ['වන', 'B-be.01'], ['අතර', 'O'], ['එය', 'O'], ['යුක්ති', 'O'], ['සහගත', 'O'], ['නොවේ', 'O'], ['.', 'O']], [['එය', 'B-ARG1'], ['සංකීර්ණ', 'B-complicate.01'], ['වන', 'O'], ['අතර', 'O'], ['එය', 'O'], ['යුක්ති', 'O'], ['සහගත', 'O'], ['නොවේ', 'O'], ['.', 'O']], [['එය', 'O'], ['සංකීර්ණ', 'O'], ['වන', 'O'], ['අතර', 'O'], ['එය', 'B-ARG1'], ['යුක්ති', 'B-justify.01'], ['සහගත', 'I-justify.01'], ['නොවේ', 'B-ARGM-NEG'], ['.', 'O']]]
# [[['එය', 'B-ARG1'], ['සංකීර්ණ', 'B-ARG8'], ['වන', 'B-be.01'], ['අතර', 'O'], ['එය', 'O'], ['යුක්ති', 'O'], ['සහගත', 'O'], ['නොවේ', 'O'], ['.', 'O']], [['එය', 'B-ARG1'], ['සංකීර්ණ', 'B-complicate.01'], ['වන', 'O'], ['අතර', 'O'], ['එය', 'O'], ['යුක්ති', 'O'], ['සහගත', 'O'], ['නොවේ', 'O'], ['.', 'O']]]

# %%
x = [[['එය', 'B-ARG1'], ['සංකීර්ණ', 'B-ARG2'], ['වන', 'B-be.01'], ['අතර', 'O'], ['එය', 'O'], ['යුක්ති', 'O'], ['සහගත', 'O'], ['නොවේ', 'O'], ['.', 'O']], [['එය', 'B-ARG1'], ['සංකීර්ණ', 'B-complicate.01'], ['වන', 'O'], ['අතර', 'O'], ['එය', 'O'], ['යුක්ති', 'O'], ['සහගත', 'O'], ['නොවේ', 'O'], ['.', 'O']], [['එය', 'O'], ['සංකීර්ණ', 'O'], ['වන', 'O'], ['අතර', 'O'], ['එය', 'B-ARG1'], ['යුක්ති', 'B-justify.01'], ['සහගත', 'I-justify.01'], ['නොවේ', 'B-ARGM-NEG'], ['.', 'O']]]
y = [[['එය', 'B-ARG1'], ['සංකීර්ණ', 'B-ARG8'], ['වන', 'B-be.01'], ['අතර', 'O'], ['එය', 'O'], ['යුක්ති', 'O'], ['සහගත', 'O'], ['නොවේ', 'O'], ['.', 'O']], [['එය', 'B-ARG1'], ['සංකීර්ණ', 'B-complicate.01'], ['වන', 'O'], ['අතර', 'O'], ['එය', 'O'], ['යුක්ති', 'O'], ['සහගත', 'O'], ['නොවේ', 'O'], ['.', 'O']]]

def getPredicateLists (mannualDta = x, predictedDta = y):
  noOfPredsInMannualDta = len(mannualDta)
  noOfPredsInPredictedDta = len(predictedDta)
  predicatesInMannualData = []
  for i in mannualDta:
    for j in i:
      # print(j)
      if "." in j[1] and "B-" in j[1]:
        predicate = j[1][2:]
        if predicate not in predicatesInMannualData:
          predicatesInMannualData.append(predicate)
          break
  predicatesInPredictedData = []
  for i in predictedDta:
    for j in i:
      if "." in j[1] and "B-" in j[1]:
        predicate = j[1][2:]
        if predicate not in predicatesInPredictedData:
          predicatesInPredictedData.append(predicate)
          break
  return predicatesInMannualData,predicatesInPredictedData

# %%
a = getPredicateLists()
print(a[0])
print(a[1])
# Out:
# ['be.01', 'complicate.01', 'justify.01']
# ['be.01', 'complicate.01']

# %%
#[a1,a2,a3,a4], [a1,a3,a2,a4] ==>> [0,2,1,3][]
#[a1,a2,a3,a4], [a2,a3,a4] ==>> [No, 0, 1, 2][]
#[a1,a2,a3,a4], [a2,a6,a4] ==>> [No, 0, No, 2][1]
#[a1,a2,a3,a4], [a1,a2,a2,a4] ==>> [0, 1, 3, 4][2]
#[a1,a2,a2,a3], [a1,a2,a3] ==>> [0, 1, No, 2][]

#sample outputs
x = ['be.01', 'complicate.01', 'justify.01']
y = ['be.01', 'complicate.01', 'complicate.01',"sdacascasc"]

def getIndexOfPredicateSentence(predicatesInMannualSent = x, predicatesInPredictedTags = y):
  predicateIndex = []
  extraIndexList = []
  copyOfPredicatesInPredictedTags = predicatesInPredictedTags.copy()
  for i in range(len(predicatesInMannualSent)):
    mannualPred = predicatesInMannualSent[i]
    for j in range(len(predicatesInPredictedTags)):
      if mannualPred == copyOfPredicatesInPredictedTags[j]:
        index = j
        predicateIndex.append(index)
        copyOfPredicatesInPredictedTags[j] = "F"
        break
      if (j==len(predicatesInPredictedTags)-1):
        predicateIndex.append("No")
  # extraTagList = [k for k in copyOfPredicatesInPredictedTags if k != "F"]
  for l in copyOfPredicatesInPredictedTags:
    # if l != "F" and l in extraTagList:
    if l != "F" and l != "No":
      indexOfExtraTag = copyOfPredicatesInPredictedTags.index(l)
      extraIndexList.append(indexOfExtraTag)
  return predicateIndex,extraIndexList

# %%
print(getIndexOfPredicateSentence())
# Out:
# ([0, 1, 'No'], [2, 3])

# %%
noOfSentences = len(mannualData)

# %%
print("Total no. of full sentences (which may have multiple predicates) = ",noOfSentences)
# Out:
# Total no. of full sentences (which may have multiple predicates) =  1732

# %%
def replaceAtsWithComma(Resultslist): #replace @@@s With Commas
  res = []
  for i in Resultslist:
    if isinstance(i, list):
      insideL = []
      for j in i:
        x = j.replace('@@@', ',')
        x = x.strip()
        insideL.append(x)
      res.append(insideL)
  # if len(res) == 1:  
  #   return res[0]
  return res

# %%
def stringToList(ini_list): #Convert a string to a list
    # print(ini_list)
    res = ini_list.replace('],[','], [').replace('] ,[','], [').replace('] , [','], [').strip()[1:-1].split("], [")
    res = [[i] for i in res]
    # print(res)
    newRes = []
    for i in res:
      res = i[0].replace(', ,', ', @@@')  #to handle exceptions when "," is in the sentence
      newRes.append(res.strip('][').split(' , ')) 
    newRes = replaceAtsWithComma(newRes)
    # print(newRes)
    return newRes

# %%
predicates = (['do.02', 'have.01'], ['do.02', 'have.01'])
def removeSenses(predicates = predicates): 
  predList1 = [i.split('.')[0] for i in predicates[0]]
  predList2 = [i.split('.')[0] for i in predicates[1]]
  return predList1,predList2

# %%
print(removeSenses())
# Out:
# (['do', 'have'], ['do', 'have'])

# %%
x = [[['එය', 'B-ARG1'], ['සංකීර්ණ', 'B-ARG2'], ['වන', 'B-be.01'], ['අතර', 'O'], ['එය', 'O'], ['යුක්ති', 'O'], ['සහගත', 'O'], ['නොවේ', 'O'], ['.', 'O']], [['එය', 'B-ARG1'], ['සංකීර්ණ', 'B-complicate.01'], ['වන', 'O'], ['අතර', 'O'], ['එය', 'O'], ['යුක්ති', 'O'], ['සහගත', 'O'], ['නොවේ', 'O'], ['.', 'O']], [['එය', 'O'], ['සංකීර්ණ', 'O'], ['වන', 'O'], ['අතර', 'O'], ['එය', 'B-ARG1'], ['යුක්ති', 'B-justify.01'], ['සහගත', 'I-justify.01'], ['නොවේ', 'B-ARGM-NEG'], ['.', 'O']]]
y = [[['එය', 'B-ARG1'], ['සංකීර්ණ', 'B-ARG8'], ['වන', 'B-be.01'], ['අතර', 'O'], ['එය', 'O'], ['යුක්ති', 'O'], ['සහගත', 'O'], ['නොවේ', 'O'], ['.', 'O']], [['එය', 'B-ARG1'], ['සංකීර්ණ', 'B-complicate.01'], ['වන', 'O'], ['අතර', 'O'], ['එය', 'O'], ['යුක්ති', 'O'], ['සහගත', 'O'], ['නොවේ', 'O'], ['.', 'O']]]

# def getMarks(s1 = x, s2 = y):
#   predicates = getPredicateLists(s1, s2) #get predicates
#   noOfWordsInTheSentence = len(s1[0]) #get no. of words in the sentence
#   noOfPredicatesInTheSentence = len(predicates[0]) #no. of predicates in the sentence
#   if noOfPredicatesInTheSentence != 0:
#     M = 100/(noOfWordsInTheSentence * noOfPredicatesInTheSentence) # marks for a single tag
#   else: #when there is no predicates in the sentence
#     M = 100/noOfWordsInTheSentence
#   marks = 100
#   marksForSentRelavantToSinglePred = M * noOfWordsInTheSentence #marks for a sentence relevat to one predicate tag
#   indexOfPredicatesInSentence = getIndexOfPredicateSentence(predicates[0], predicates[1]) #indexes of predicates
#   marks -= 0.2 * len(indexOfPredicatesInSentence[1]) *  marksForSentRelavantToSinglePred #reduce marks for Wrong predicted predicates (extra ones)
#   for index in indexOfPredicatesInSentence[0]: #iterate through each predicate
#     if index == 'No': #reduce marks for lacking a predicate
#       marks -= marksForSentRelavantToSinglePred
#     else:
#       #compare tags and reduce marks for wrong tags
#       for i in range(noOfWordsInTheSentence):
#         if s1[index][i][1] != s2[index][i][1]: #if the predicted tag is wrong
#           marks -= (0.2) * M 
#   return marks

# %%
def getMarks(s1 = x, s2 = y):
  predicates = getPredicateLists(s1, s2) #get predicates
  # print(predicates)
  noOfWordsInTheSentence = len(s1[0]) #get no. of words in the sentence
  # print(noOfWordsInTheSentence)
  noOfPredicatesInTheSentence = len(predicates[0]) #no. of predicates in the sentence
  # print(noOfPredicatesInTheSentence)
  predVerbs = removeSenses(predicates)
  # print(predVerbs)
  indexOfPredicatesInSentence = getIndexOfPredicateSentence(predVerbs[0], predVerbs[1]) #indexes of predicates
  # print(indexOfPredicatesInSentence)
  extraIndexes = indexOfPredicatesInSentence[1]
  marks = 0
  if noOfPredicatesInTheSentence > 0: #when there are predicates
    marksForSingleSentRelavantAPred = 100 / noOfPredicatesInTheSentence #marks for a tag list relevant to single predicate
    for k in range(len(indexOfPredicatesInSentence[0])): #iterate through indexes (mapping to s1-pred with s2 preds)
      predTags = [] #all the predicate tags in the sentence relevant to single predicate
      for i in range(noOfWordsInTheSentence): #iterate through words in the sentence
        # print(s1)
        # print(s2)
        if '.' in s1[k][i][1]: 
          predTags.append(s1[k][i][1])
      if len(predTags) == 0:
        marksForSRLTag = marksForSingleSentRelavantAPred / (noOfWordsInTheSentence - len(predTags))
      elif noOfWordsInTheSentence > len(predTags): #if all the words in the sentence are predicates (for a single predicate)
        marksForPredVerbTag = (marksForSingleSentRelavantAPred * 0.45) / len(predTags)
        marksForPredSense = marksForSingleSentRelavantAPred * 0.05 / len(predTags)
        marksForSRLTag = marksForSingleSentRelavantAPred * 0.5 / (noOfWordsInTheSentence - len(predTags))
      elif noOfWordsInTheSentence == len(predTags):
        marksForPredVerbTag = (marksForSingleSentRelavantAPred *0.9) / len(predTags)
        marksForPredSense = (marksForSingleSentRelavantAPred * 0.1) / len(predTags)
      for i in range(noOfWordsInTheSentence):
        if indexOfPredicatesInSentence[0][k] != 'No':
          if ('.' in s1[k][i][1]) and ('.' in s2[indexOfPredicatesInSentence[0][k]][i][1]):
            if s1[k][i][1].split('.')[0] == s2[indexOfPredicatesInSentence[0][k]][i][1].split('.')[0]:
              marks += marksForPredVerbTag
              if s1[k][i][1].split('.')[1] == s2[indexOfPredicatesInSentence[0][k]][i][1].split('.')[1]:
                marks += marksForPredSense
          elif s1[k][i][1] == s2[indexOfPredicatesInSentence[0][k]][i][1]:
            marks += marksForSRLTag
            ##code for extra tags
  elif noOfPredicatesInTheSentence == 0:
    # print(s1)
    # print(s2)
    marksForSingleTag = 100 / noOfWordsInTheSentence
    for i in range(noOfWordsInTheSentence):
      if s1[0][i][1] == s2[0][i][1]:
        marks += marksForSingleTag
    if len(predicates[1]) != 0:
      marks -= 5 * len(predicates[1])
  #----------------------------------------------------handle extra predicates----------------------
  noindexList = [] #indexes of 'No' preds
  if len(indexOfPredicatesInSentence[0]) != 0:
    for i in range(len(indexOfPredicatesInSentence[0])):
      if indexOfPredicatesInSentence[0][i] == 'No':
        noindexList.append(i)
  noOfNoIndexes = len(noindexList)
  noOfExtraIndexes = len(extraIndexes)
  remainingExtraIndexes = len(extraIndexes)
  if noOfNoIndexes > 0 and noOfNoIndexes < noOfExtraIndexes: #when No of missing predicates are lesser than extra predicates
    noOfPredTags = 0
    noCheckedOfExtraIndexes = 0
    for i in range(noOfNoIndexes): #loop through each "No" predicate
      for j in range(noOfWordsInTheSentence): #loop through each word
        if '.' in s1[noindexList[i]][j][1]:
          noOfPredTags += 1
      if noOfWordsInTheSentence != noOfPredTags:
        M = (marksForSingleSentRelavantAPred * 0.5) / (noOfWordsInTheSentence - noOfPredTags)
        for j in range(noOfWordsInTheSentence):
          if s1[noindexList[i]][j][1] == s2[noCheckedOfExtraIndexes][j][1]:
            marks += M
      noCheckedOfExtraIndexes += 1
    marks -= 5 * (noOfExtraIndexes - noCheckedOfExtraIndexes)
  if noOfNoIndexes > 0 and noOfNoIndexes > noOfExtraIndexes: #when No of missing predicates are greater than extra predicates
    noOfPredTags = 0
    noCheckedOfExtraIndexes = 0
    for i in range(noOfExtraIndexes): #loop through each extra predicate
      for j in range(noOfWordsInTheSentence): #loop through each word
        if '.' in s1[noindexList[i]][j][1]:
          noOfPredTags += 1
      if noOfWordsInTheSentence != noOfPredTags:
        M = (marksForSingleSentRelavantAPred * 0.5) / (noOfWordsInTheSentence - noOfPredTags)
        for j in range(noOfWordsInTheSentence):
          if s1[noindexList[i]][j][1] == s2[noCheckedOfExtraIndexes][j][1]:
            marks += M
      noCheckedOfExtraIndexes += 1
  return marks

# %%
print(getMarks())
# Out:
# 64.58333333333334

# %%
noOfFullyCorrectSentences = 0
noOfSentencesWithCorrectPredsWithSensesNotConsideringSRL = 0
noOfSentencesWithCorrectPredsNotConsideringSRLAndSenses = 0
overallAccuarcy = 0
sentCat1 = 0
sentCat2 = 0
sentCat3 = 0
sentCat4 = 0
for index, row in mannualData.iterrows():
# for i in range(1):
  if row['manual annotation'] != '[ ]':
    s1 = stringToList(row['manual annotation'])
    for u in s1:
      if u[-1] != '. O':
        u.append('. O')
  else:
    s1 = []
  if row['predicted annotation'] != '[ ]':
    s2 = stringToList(row['predicted annotation'])
    for u in s2:
      if u[-1] != '. O':
        u.append('. O')
  else:
    s2 = []
  # s1 = [['එසේ B-ARGM-DIS', 'වුවද I-ARGM-DIS', ', O', 'තීරණය B-ARG1', 'දැනටමත් B-ARGM-TMP', 'සම්මත B-adopt.01', 'කර I-adopt.01', 'ඇත B-have.01', '. O']]
  # s2 = [['එසේ B-ARGM-DIS', 'වුවද O', ', O', 'තීරණය O', 'දැනටමත් O', 'සම්මත O', 'කර O', 'ඇත B-have.01', '. O']]
  print(s1)
  print(s2)
  twoSentences = makeLists(s1, s2) #([[['එය', 'B-ARG0'], ['තවත්', 'B-ARG1'], ['බොහෝ', 'O'], ['දේ', 'O'], ['කළ', 'B-do.02'], ['යුතුව', 'O'], ['තිබුණි', 'O'], ['.', 'O']], [['එය', 'O'], ['තවත්', 'O'], ['බොහෝ', 'O'], ['දේ', 'O'], ['කළ', 'O'], ['යුතුව', 'O'], ['තිබුණි', 'B-have.01'], ['.', 'O']]], [[['එය', 'B-ARG0'], ['තවත්', 'B-ARG1'], ['බොහෝ', 'O'], ['දේ', 'O'], ['කළ', 'B-do.02'], ['යුතුව', 'O'], ['තිබුණි', 'O'], ['.', 'O']], [['එය', 'O'], ['තවත්', 'O'], ['බොහෝ', 'O'], ['දේ', 'O'], ['කළ', 'O'], ['යුතුව', 'O'], ['තිබුණි', 'B-have.01'], ['.', 'O']]])
  # print(twoSentences)
  if twoSentences[0] == twoSentences[1]: # To check whether the sentences are fully tagged correctly (srl + predicate + sense)
    noOfFullyCorrectSentences += 1
  predicates = getPredicateLists(twoSentences[0], twoSentences[1]) #(['do.02', 'have.01'], ['do.02', 'have.01'])
  if predicates[0] == predicates[1]: #To check whether predicates of the sentences are 100% correctly predcited with the senses (SRL tags are not considered)
    noOfSentencesWithCorrectPredsWithSensesNotConsideringSRL += 1 
  predicateVerbs = removeSenses(predicates)
  if predicateVerbs[0] == predicateVerbs[1]: #To check whether predicate verbs of the sentences are 100% correctly predcited (SRL tags and senses are not considered)
    noOfSentencesWithCorrectPredsNotConsideringSRLAndSenses += 1
  if s1 == [] and s2 == []:
    marks = 100
  elif s1 != [] and s2 == []:
    marks = 0
  elif s1 == [] and s2 != []:
    marks = 0
  else:
    # print(s1)
    marks = getMarks(twoSentences[0], twoSentences[1])
  print(marks)
  overallAccuarcy += marks/100
  if 80 <= marks:
    sentCat1 += 1
  elif 60 <= marks < 80:
    sentCat2 += 1
  elif 30 <= marks < 60:
    sentCat3 += 1
  else:
    sentCat4 += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# [['ඔවුන් O', 'තීරණ O', 'ගන්නේ B-do.01', 'නැහැ O', '. O']]
# 62.5
# [['මෙම B-ARG1', 'අවස්ථාවන් I-ARG1', 'සක්\u200dරීයව B-ARGM-MNR', 'භාවිතා B-use.01', 'කරමු I-use.01', '. O']]
# [['මෙම B-ARG1', 'අවස්ථාවන් I-ARG1', 'සක්\u200dරීයව B-ARGM-MNR', 'භාවිතා B-use.01', 'කරමු I-use.01', '. O']]
# 100.0
# [['එහෙත් B-ARGM-DIS', 'අපි B-ARG0', 'අමතර B-ARG1', 'වටිනාකමක් I-ARG1', 'ලබා B-provide.01', 'දී I-provide.01', 'නැත I-ARG1', '. O']]
# [['එහෙත් B-ARGM-DIS', 'අපි B-ARG0', 'අමතර O', 'වටිනාකමක් B-ARG1', 'ලබා B-provide.01', 'දී O', 'නැත I-ARG1', '. O']]
# 58.33333333333334
# [['අපි B-ARG0', 'දැන් B-ARGM-TMP', 'රැස්වීම B-ARG1', 'අත්හිටුවන්නෙමු B-suspend.01', '. O']]
# [['අපි B-ARG0', 'දැන් B-ARGM-TMP', 'රැස්වීම B-ARG1', 'අත්හිටුවන්නෙමු B-suspend.01', '. O']]
# 100.0
# [['එය B-ARG0', 'ඡන්දය B-ARG1', 'ප්\u200dරකාශ I-ARG1', 'කිරීමේ I-ARG1', 'කාලය I-ARG1', 'අවසන් B-conclude.01', 'කරයි I-conclude.01', '. O']]
# [['එය B-ARG0', 'ඡන්දය O', 'ප්\u200dරකාශ B-ARG1', 'කිරීමේ I-ARG1', 'කාලය I-ARG1', 'අවසන් B-conclude.01', 'කරයි I-conclude.01', '. O']]
# 83.33333333333333
# [['මම B-ARG0', 'මෙයින් B-ARG2', 'නිගමන B-ARG1', 'දෙකක් I-ARG1', 'උකහා B-draw.02', 'ගනිමි I-draw.02', '. O']]
# [['මම B-ARG0', 'මෙයින් B-ARG2', 'නිගමන B-ARG1', 'දෙකක් I-ARG1', 'උකහා B-draw.02', 'ගනිමි I-draw.02', '. O']]
# 100.0
# [['මෙය B-ARG0', 'කඩිනමින් B-ARG1', 'කළ O', 'යුතුය B-need.01', '. O']]
# [['මෙය B-ARG0', 'කඩිනමින් B-ARG1', 'කළ O', 'යුතුය B-need.01', '. O']]
# 100.0
# [['වෙනත් B-ARG1', 'මාර්ගයක් I-ARG1', 'නැත I-ARG1', '. O']]
# [['වෙනත් B-ARG1', 'මාර්ගයක් I-ARG1', 'නැත I-ARG1', '. O  B-be.02', '. O']]
# 100.0
# [['එය B-ARG0', 'ලබා B-give.01', 'දෙනවා I-give.01', 'හේතු B-ARG1', 'ඉමහත් I-ARG1', 'කනස්සල්ලට I-ARG1', '. O']]
# [['එය B-ARG0', 'ලබා B-give.01', 'දෙනවා I-give.01', 'හේතු O', 'ඉමහත් B-ARG1', 'කනස්සල්ලට I-ARG1', '. O']]
# 80.0
# [['යුරෝපයෙන් B-ARGM-LOC', 'පිටත I-ARGM-LOC', 'ද B-ARGM-ADV', 'ඊශ්\u200dරායෙලයට B-ARG0', 'බලවත් B-ARG1', 'සගයන් I-ARG1', 'ඇත B-have.03', '. O']]
# [['යුරෝපයෙන් B-ARGM-LOC', 'පිටත I-ARGM-LOC', 'ද B-ARGM-ADV', 'ඊශ්\u200dරායෙලයට B-ARG0', 'බලවත් B-ARG1', 'සගයන් I-ARG1', 'ඇත B-have.03', '. O']]
# 100.0
# [['වාසනාවකට B-ARGM-ADV', 'මෙන් I-ARGM-ADV', ', O', 'සෑම O', 'දෙයක්ම B-ARG1', 'තිබේ B-be.01', '. O']]
# [['වාසනාවකට B-ARGM-ADV', 'මෙන් O', ', O', 'සෑම O', 'දෙයක්ම B-ARG1', 'තිබේ B-be.01', '. O']]
# 91.66666666666667
# [['කාල B-ARG1', 'සීමාවක් I-ARG1', 'නොමැත I-ARG1', '. O']]
# [['කාල B-ARG1', 'සීමාවක් I-ARG1', 'නොමැත I-ARG1', '. O  B-be.02', '. O']]
# 100.0
# [['ඇත්තටම B-ARGM-ADV', 'කළ B-do.01', 'යුතු B-ARGM-MOD', 'දේ B-ARG1', 'ඔබ O', 'දන්නවා O', '. O'], ['ඇත්තටම B-ARG1', 'කළ I-ARG1', 'යුතු I-ARG1', 'දේ I-ARG1', 'ඔබ B-ARG0', 'දන්නවා B-know.01', '. O']]
# [['ඇත්තටම O', 'කළ B-do.01', 'යුතු O', 'දේ O', 'ඔබ O', 'දන්නවා O', '. O'], ['ඇත්තටම B-ARG1', 'කළ O', 'යුතු I-ARG1', 'දේ I-ARG1', 'ඔබ B-ARG0', 'දන්නවා B-know.01', '. O']]
# 83.33333333333333
# [['ගැටලුව B-ARG1', 'පවතින්නේ B-ARG2', 'මෙහිදීය I-ARG2', '. O'], ['ගැටලුව B-ARG1', 'පවතින්නේ B-lie.07', 'මෙහිදීය O', '. O']]
# [['ගැටලුව B-ARG1', 'පවතින්නේ B-lie.07', 'මෙහිදීය O', '. O']]
# 50.0
# [['ආර්ථික B-ARG1', 'මන්දගාමිත්වය I-ARG1', 'විශේෂයෙන් B-ARG2', 'දැඩි I-ARG2', 'ය B-be.01', '. O']]
# [['ආර්ථික B-ARG1', 'මන්දගාමිත්වය O', 'විශේෂයෙන් B-ARG2', 'දැඩි I-ARG2', 'ය B-be.01', '. O']]
# 90.0
# [['එය B-ARG1', 'ප්\u200dරබන්ධයක්ද B-ARG2', '? O', '. O']]
# [['එය B-ARG1', 'ප්\u200dරබන්ධයක්ද O', '? O', '. O']]
# 75.0
# [['ප්\u200dරතිඑල B-ARG2', 'ගැන I-ARG2', 'අපට B-ARG1', 'ආඩම්බර I-ARG2', 'විය B-be.01', 'හැකිය B-ARGM-MOD', '. O']]
# [['ප්\u200dරතිඑල B-ARG2', 'ගැන I-ARG2', 'අපට B-ARG1', 'ආඩම්බර I-ARG2', 'විය B-be.01', 'හැකිය B-ARGM-MOD', '. O']]
# 100.0
# [['අපට B-ARG0', 'සිවිල් B-ARG1', 'සංවාදයක් I-ARG1', 'තිබුණේ B-have.03', 'නම් O', 'පමණි O', '. O']]
# [['අපට B-ARG0', 'සිවිල් B-ARG1', 'සංවාදයක් I-ARG1', 'තිබුණේ B-have.03', 'නම් O', 'පමණි O', '. O']]
# 99.99999999999999
# [['එක්සත් B-ARG0', 'ජාතීන්ගේ I-ARG0', 'ආරක්ෂක I-ARG0', 'මණ්ඩලය I-ARG0', 'විසින් I-ARG0', 'යෝජනාවක් B-ARG1', 'සම්මත B-adopt.01', 'කර I-adopt.01', 'ගෙන I-adopt.01', 'තිබෙයි I-adopt.01', '. O']]
# [['එක්සත් B-ARG0', 'ජාතීන්ගේ I-ARG0', 'ආරක්ෂක I-ARG0', 'මණ්ඩලය I-ARG0', 'විසින් O', 'යෝජනාවක් B-ARG1', 'සම්මත B-adopt.01', 'කර I-adopt.01', 'ගෙන I-adopt.01', 'තිබෙයි I-adopt.01', '. O']]
# 92.85714285714286
# [['අප B-ARG0', 'ජීවත් B-live.01', 'වන්නේ I-live.01', 'නව B-ARGM-TMP', 'යුගයක I-ARGM-TMP', 'ය O', '. O'], ['අප O', 'ජීවත් O', 'වන්නේ O', 'නව O', 'යුගයක O', 'ය B-be.03', '. O']]
# [['අප B-ARG0', 'ජීවත් B-live.01', 'වන්නේ I-live.01', 'නව B-ARGM-TMP', 'යුගයක O', 'ය O', '. O'], ['අප O', 'ජීවත් O', 'වන්නේ O', 'නව O', 'යුගයක O', 'ය B-be.03', '. O']]
# 95.0
# [['සංගමය B-ARG0', 'මෙහි B-ARGM-LOC', 'වැරදි B-ARG1', 'ප්\u200dරමුඛතා I-ARG1', 'තෝරා B-choose.01', 'ගනී I-choose.01', '. O']]
# [['සංගමය B-ARG0', 'මෙහි B-ARGM-LOC', 'වැරදි B-ARG1', 'ප්\u200dරමුඛතා I-ARG1', 'තෝරා B-choose.01', 'ගනී I-choose.01', '. O']]
# 100.0
# [['ඔහුගේ B-ARG1', 'රජය I-ARG1', 'බරපතල B-ARG2', 'මූල්\u200dය I-ARG2', 'අර්බුදයක I-ARG2', 'සිටී B-be.01', '. O']]
# [['ඔහුගේ B-ARG1', 'රජය I-ARG1', 'බරපතල B-ARG2', 'මූල්\u200dය I-ARG2', 'අර්බුදයක I-ARG2', 'සිටී B-be.01', '. O']]
# 100.0
# [['මෙයින් B-ARG0', 'අදහස් B-mean.01', 'කරන්නේ I-mean.01', 'ප්\u200dරතිවිරුද්ධ B-ARG1', 'ආස්ථානයක් I-ARG1', 'ගැනීම I-ARG1', 'නොවේ B-ARGM-NEG', '. O'], ['මෙයින් O', 'අදහස් O', 'කරන්නේ O', 'ප්\u200dරතිවිරුද්ධ B-ARG0', 'ආස්ථානයක් B-ARG1', 'ගැනීම B-adopting.01', 'නොවේ O', '. O']]
# [['මෙයින් B-ARG0', 'අදහස් B-mean.01', 'කරන්නේ I-mean.01', 'ප්\u200dරතිවිරුද්ධ B-ARG1', 'ආස්ථානයක් O', 'ගැනීම O', 'නොවේ O', '. O']]
# 37.5
# [['එය B-ARG1', 'තේරුම්ගත B-ARG2', 'හැකි I-ARG2', 'ය B-be.01', '. O']]
# [['එය B-ARG1', 'තේරුම්ගත B-ARG2', 'හැකි O', 'ය B-be.01', '. O']]
# 87.5
# [['ඒ B-ARGM-DIS', 'නිසා I-ARGM-DIS', 'මම B-ARG0', 'පක්ෂව B-ARG1', 'ඡන්දය B-vote.01', 'දුන්නා I-vote.01', '. O']]
# [['ඒ B-ARGM-DIS', 'නිසා I-ARGM-DIS', 'මම B-ARG0', 'පක්ෂව B-ARG1', 'ඡන්දය O', 'දුන්නා B-vote.01', '. O']]
# 50.0
# [['යුරෝපා B-ARG2', 'සංගමය I-ARG2', 'සඳහා I-ARG2', 'වන්නේ I-ARG2', 'එයයි I-ARG1', '. O']]
# [['යුරෝපා B-ARG1', 'සංගමය I-ARG1', 'සඳහා B-ARG2', 'වන්නේ O', 'එයයි O', '. O']]
# 16.666666666666668
# [['කොමසාරිස් B-ARGM-DIS', ', O', 'මම B-ARG0', 'ඔබගේ B-ARG1', 'පිළිතුර I-ARG1', 'බෙහෙවින් B-ARGM-ADV', 'අගය B-appreciate.02', 'කරමි I-appreciate.02', '. O']]
# [['කොමසාරිස් B-ARGM-DIS', ', O', 'මම B-ARG0', 'ඔබගේ B-ARG1', 'පිළිතුර I-ARG1', 'බෙහෙවින් B-ARGM-ADV', 'අගය B-appreciate.02', 'කරමි I-appreciate.02', '. O']]
# 100.0
# [['සැබෑ B-ARG1', 'නිෂ්පාදකයාගේ I-ARG1', 'මිල I-ARG1', 'භයානක B-ARGM-MNR', 'ලෙස I-ARGM-MNR', 'පහත B-fall.01', 'වැටේ I-fall.01', '. O']]
# [['සැබෑ B-ARG1', 'නිෂ්පාදකයාගේ I-ARG1', 'මිල I-ARG1', 'භයානක O', 'ලෙස O', 'පහත B-fall.01', 'වැටේ I-fall.01', '. O']]
# 83.33333333333333
# [['මේවා B-ARG1', 'ප්\u200dරධාන B-ARG2', 'ප්\u200dරතිසංස්කරණ I-ARG2', '. O']]
# [['මේවා B-ARG1', 'ප්\u200dරධාන B-ARG2', 'ප්\u200dරතිසංස්කරණ I-ARG2', '. O  B-be.01', '. O']]
# 100.0
# [['එය B-ARG1', 'කටුක B-ARG2', 'පාඩමක් I-ARG2', 'විය B-be.01', '. O']]
# [['එය B-ARG1', 'කටුක B-ARG2', 'පාඩමක් I-ARG2', 'විය B-be.01', '. O']]
# 100.0
# [['ඔවුන් B-ARG0', 'හමාස් B-ARG1', 'පක්ෂයට I-ARG1', 'ඡන්දය B-vote.01', 'දෙන්නේ I-vote.01', 'ඇයි B-ARGM-CAU', '? O', '. O']]
# [['ඔවුන් B-ARG0', 'හමාස් B-ARG1', 'පක්ෂයට O', 'ඡන්දය B-vote.01', 'දෙන්නේ O', 'ඇයි B-ARGM-CAU', '? O', '. O']]
# 66.66666666666667
# [['ඒවා B-ARG1', 'පදනම් B-base.02', 'වී I-base.02', 'ඇත්තේ O', 'එකම B-ARG2', 'මූලධර්ම I-ARG2', 'මත O', 'ය O', '. O'], ['ඒවා O', 'පදනම් O', 'වී O', 'ඇත්තේ O', 'එකම O', 'මූලධර්ම O', 'මත O', 'ය B-be.03', '. O']]
# [['ඒවා B-ARG1', 'පදනම් B-base.02', 'වී I-base.02', 'ඇත්තේ O', 'එකම B-ARG2', 'මූලධර්ම I-ARG2', 'මත O', 'ය O', '. O'], ['ඒවා O', 'පදනම් O', 'වී O', 'ඇත්තේ O', 'එකම O', 'මූලධර්ම O', 'මත O', 'ය B-be.03', '. O']]
# 99.99999999999999
# [['පැහැරගැනීම් B-ARG1', 'දිගටම B-continue.01', '. O']]
# [['පැහැරගැනීම් B-ARG1', 'දිගටම B-continue.01', '. O']]
# 100.0
# [['කෙසේ B-ARGM-DIS', 'වෙතත් B-ARGM-DIS', ', O', 'මට B-ARG0', 'වෙන්කිරීම් B-ARG1', 'කිහිපයක් I-ARG1', 'තිබේ B-have.03', '. O']]
# [['කෙසේ B-ARGM-DIS', 'වෙතත් O', ', O', 'මට B-ARG0', 'වෙන්කිරීම් B-ARG1', 'කිහිපයක් I-ARG1', 'තිබේ B-have.03', '. O']]
# 92.85714285714286
# [['ඔවුන් B-ARG0', 'මිනිසුන්ගේ B-ARG1', 'මානසිකත්වයට I-ARG1', 'හා I-ARG1', 'අපේක්ෂාවන්ට I-ARG1', 'ගැලපේ B-match.01', '. O']]
# [['ඔවුන් B-ARG0', 'මිනිසුන්ගේ B-ARG1', 'මානසිකත්වයට I-ARG1', 'හා I-ARG1', 'අපේක්ෂාවන්ට O', 'ගැලපේ B-match.01', '. O']]
# 91.66666666666667
# [['රුමේනියාවේ B-ARG1', 'ඊසානදිග I-ARG1', 'කොටස I-ARG1', 'දැඩි B-ARGM-MNR', 'ලෙස I-ARGM-MNR', 'පීඩාවට B-affect.01', 'පත් I-affect.01', 'විය I-affect.01', '. O']]
# [['රුමේනියාවේ B-ARG1', 'ඊසානදිග I-ARG1', 'කොටස I-ARG1', 'දැඩි B-ARGM-MNR', 'ලෙස O', 'පීඩාවට B-affect.01', 'පත් O', 'විය O', '. O']]
# 58.333333333333336
# [['යුරෝපා B-ARG1', 'සංගමයට I-ARG1', 'උණුසුම B-ARG2', 'සහතික I-ARG2', 'කළ I-ARG2', 'නොහැක්කේ I-ARG2', 'ඇයි B-ARGM-CAU', '? O', '. O'], ['යුරෝපා B-ARG1', 'සංගමයට I-ARG1', 'උණුසුම I-ARG1', 'සහතික B-guarantee.01', 'කළ I-guarantee.01', 'නොහැක්කේ O', 'ඇයි O', '? O', '. O']]
# [['යුරෝපා B-ARG1', 'සංගමයට I-ARG1', 'උණුසුම I-ARG1', 'සහතික B-guarantee.01', 'කළ I-guarantee.01', 'නොහැක්කේ O', 'ඇයි O', '? O', '. O']]
# 44.44444444444444
# [['ගෝලීය B-ARG1', 'විසඳුම් I-ARG1', 'අවශ්\u200dය B-need.01', 'ගෝලීය B-ARG0', 'ගැටලු I-ARG0', 'තිබේ O', '. O'], ['ගෝලීය B-ARG1', 'විසඳුම් I-ARG1', 'අවශ්\u200dය I-ARG1', 'ගෝලීය I-ARG1', 'ගැටලු I-ARG1', 'තිබේ B-be.02', '. O']]
# [['ගෝලීය B-ARG0', 'විසඳුම් B-ARG1', 'අවශ්\u200dය B-need.01', 'ගෝලීය I-ARG0', 'ගැටලු I-ARG0', 'තිබේ O', '. O'], ['ගෝලීය B-ARG1', 'විසඳුම් I-ARG1', 'අවශ්\u200dය I-ARG1', 'ගෝලීය I-ARG1', 'ගැටලු I-ARG1', 'තිබේ B-be.02', '. O']]
# 87.49999999999999
# [['මෙය B-ARG0', 'ජීවිතයේ B-ARG1', 'සෑම I-ARG1', 'අංශයක් I-ARG1', 'ගැනම I-ARG1', 'සැලකිලිමත් B-concern.01', 'වේ I-concern.01', '. O']]
# [['මෙය B-ARG0', 'ජීවිතයේ B-ARG1', 'සෑම I-ARG1', 'අංශයක් I-ARG1', 'ගැනම O', 'සැලකිලිමත් B-concern.01', 'වේ I-concern.01', '. O']]
# 91.66666666666667
# [['බෙලාරුස් B-ARG1', 'හි I-ARG1', 'ප්\u200dරජාතන්ත්\u200dරීයකරණයේ I-ARG1', 'ප්\u200dරගතිය I-ARG1', 'සතුටුදායකද O', '? O', '. O']]
# [['බෙලාරුස් B-ARG1', 'හි I-ARG1', 'ප්\u200dරජාතන්ත්\u200dරීයකරණයේ I-ARG1', 'ප්\u200dරගතිය I-ARG1', 'සතුටුදායකද O', '? O', '. O']]
# 100.00000000000001
# [['මම B-ARG0', 'මෙය B-ARG1', 'උච්චාරණය B-sort_out.02', 'කරමි I-sort_out.02', '. O']]
# [['මම B-ARG0', 'මෙය B-ARG1', 'උච්චාරණය B-sort_out.02', 'කරමි I-sort_out.02', '. O']]
# 100.00000000000001
# [['වෙළඳපොළ B-ARG0', 'එය B-ARG1', 'විසින්ම I-ARG1', 'නියාමනය B-regulate.01', 'කරයි I-regulate.01', '. O']]
# [['වෙළඳපොළ B-ARG0', 'එය O', 'විසින්ම I-ARG1', 'නියාමනය B-regulate.01', 'කරයි I-regulate.01', '. O']]
# 87.5
# [['පහත B-follow.01', 'සඳහන් O', 'ප්\u200dරශ්න B-ARG1', 'සභාවට O', 'යොමු O', 'කෙරේ O', '. O'], ['පහත B-ARG1', 'සඳහන් I-ARG1', 'ප්\u200dරශ්න I-ARG1', 'සභාවට B-ARG2', 'යොමු B-address.01', 'කෙරේ I-address.01', '. O']]
# [['පහත B-follow.01', 'සඳහන් O', 'ප්\u200dරශ්න B-ARG1', 'සභාවට O', 'යොමු O', 'කෙරේ O', '. O'], ['පහත B-ARG1', 'සඳහන් O', 'ප්\u200dරශ්න I-ARG1', 'සභාවට B-ARG2', 'යොමු B-address.01', 'කෙරේ I-address.01', '. O']]
# 95.0
# [['අපගේ B-ARG1', 'වාර්තාකරු I-ARG1', 'නිවැරදි B-ARG2', 'මාවතේ I-ARG2', 'ය B-be.01', '. O']]
# [['අපගේ B-ARG1', 'වාර්තාකරු I-ARG1', 'නිවැරදි B-ARG2', 'මාවතේ I-ARG2', 'ය B-be.01', '. O']]
# 100.0
# [['එම B-ARG1', 'සමුළුව I-ARG1', 'වැදගත් B-ARG2', 'අවස්ථාවක් I-ARG2', 'විය B-be.01', '. O']]
# [['එම B-ARG1', 'සමුළුව O', 'වැදගත් O', 'අවස්ථාවක් B-ARG2', 'විය B-be.01', '. O']]
# 70.0
# [['අපි B-ARG1', 'ඉන්නේ B-be.01', 'දුෂ්කර B-ARG2', 'තත්වයක I-ARG2', '. O']]
# [['අපි B-ARG1', 'ඉන්නේ B-be.01', 'දුෂ්කර B-ARG2', 'තත්වයක I-ARG2', '. O']]
# 100.0
# [['දේශපාලන B-ARG1', 'පරිච්ඡේද I-ARG1', 'විවෘත B-open.01', 'කළ I-open.01', 'හැක්කේ B-ARGM-MOD', 'එවිට B-ARGM-TMP', 'පමණි I-ARGM-TMP', '. O']]
# [['දේශපාලන B-ARG1', 'පරිච්ඡේද I-ARG1', 'විවෘත B-open.01', 'කළ I-open.01', 'හැක්කේ B-ARGM-MOD', 'එවිට B-ARGM-TMP', 'පමණි I-ARGM-TMP', '. O']]
# 99.99999999999999
# [['දින B-ARGM-TMP', '3 I-ARGM-TMP', 'ක් I-ARGM-TMP', 'තුළ I-ARGM-TMP', 'ඉල්ලීම් B-ARG1', '76 I-ARG1', 'ක් I-ARG1', 'විභාග B-examine.01', 'කරන I-examine.01', 'ලදී I-examine.01', '. O']]
# [['දින B-ARGM-TMP', '3 I-ARGM-TMP', 'ක් I-ARGM-TMP', 'තුළ I-ARGM-TMP', 'ඉල්ලීම් B-ARG1', '76 I-ARG1', 'ක් O', 'විභාග B-examine.01', 'කරන I-examine.01', 'ලදී I-examine.01', '. O']]
# 93.75
# [['මේ B-ARGM-TMP', 'මොහොතේ I-ARGM-TMP', 'බොහෝ B-ARG1', 'වැදගත් I-ARG1', 'ව්\u200dයාපෘති I-ARG1', 'තිබේ B-be.02', '. O']]
# [['මේ B-ARGM-TMP', 'මොහොතේ I-ARGM-TMP', 'බොහෝ B-ARG1', 'වැදගත් I-ARG1', 'ව්\u200dයාපෘති I-ARG1', 'තිබේ B-be.02', '. O']]
# 100.0
# [['ඔහු B-ARG0', 'හොඳ B-ARG1', 'වැඩක් I-ARG1', 'කර B-do.02', 'ඇත O', '. O'], ['ඔහු O', 'හොඳ O', 'වැඩක් O', 'කර O', 'ඇත B-have.01', '. O']]
# [['ඔහු B-ARG0', 'හොඳ O', 'වැඩක් B-ARG1', 'කර B-do.02', 'ඇත O', '. O'], ['ඔහු O', 'හොඳ O', 'වැඩක් O', 'කර O', 'ඇත B-have.01', '. O']]
# 90.0
# [['අපට B-ARG0', 'විශිෂ්ට B-ARG1', 'නීති I-ARG1', 'සම්පාදනයක් I-ARG1', 'තිබේ B-have.03', '. O']]
# [['අපට B-ARG0', 'විශිෂ්ට B-ARG1', 'නීති O', 'සම්පාදනයක් O', 'තිබේ B-have.03', '. O']]
# 80.0
# [['අවිනිශ්චිතතාවය B-ARG1', 'විශ්වාසයේ B-ARG2', 'ප්\u200dරතිවිරුද්ධයයි I-ARG2', '. O']]
# [['අවිනිශ්චිතතාවය B-ARG1', 'විශ්වාසයේ B-be.01', 'ප්\u200dරතිවිරුද්ධයයි B-ARG2', '. O']]
# 45.0
# [['යුරෝපා B-ARG1', 'සංගමය I-ARG1', 'සම්බන්ධ B-involve.01', 'වන්නේ I-involve.01', 'කෙසේද B-ARGM-MNR', '? O', '. O'], ['යුරෝපා O', 'සංගමය O', 'සම්බන්ධ O', 'වන්නේ B-be.03', 'කෙසේද O', '? O', '. O']]
# [['යුරෝපා B-ARG1', 'සංගමය I-ARG1', 'සම්බන්ධ B-involve.01', 'වන්නේ O', 'කෙසේද B-ARGM-MNR', '? O', '. O'], ['යුරෝපා O', 'සංගමය O', 'සම්බන්ධ O', 'වන්නේ B-be.03', 'කෙසේද O', '? O', '. O']]
# 87.50000000000001
# [['මම B-ARG1', 'මේ B-ARG4', 'කාරණයට I-ARG4', 'නැවත B-return.01', 'නො B-ARGM-NEG', 'එන්නෙමි I-return.01', '. O']]
# [['මම B-ARG1', 'මේ B-ARG4', 'කාරණයට I-ARG4', 'නැවත B-return.01', 'නො B-ARGM-NEG', 'එන්නෙමි O', '. O']]
# 75.0
# [['කෙසේ B-ARGM-DIS', 'වෙතත් B-ARGM-DIS', ', O', 'මට B-ARG0', 'වෙන් B-ARG1', 'කිරීම් I-ARG1', 'දෙකක් I-ARG1', 'තිබේ B-have.03', '. O']]
# [['කෙසේ B-ARGM-DIS', 'වෙතත් O', ', O', 'මට B-ARG0', 'වෙන් O', 'කිරීම් O', 'දෙකක් B-ARG1', 'තිබේ B-have.03', '. O']]
# 75.0
# [['මට B-ARG0', 'ඔබට B-ARG2', 'පිළිතුර B-ARG1', 'දිය B-give.01', 'හැකිය B-ARGM-MOD', '. O']]
# [['මට B-ARG0', 'ඔබට B-ARG2', 'පිළිතුර B-ARG1', 'දිය B-give.01', 'හැකිය B-ARGM-MOD', '. O']]
# 100.0
# [['අපට B-ARG0', 'එය B-ARG1', 'ප්\u200dරතික්ෂේප B-deny.01', 'කළ I-deny.01', 'නොහැකිය O', '. O']]
# [['අපට B-ARG0', 'එය B-ARG1', 'ප්\u200dරතික්ෂේප B-deny.01', 'කළ I-deny.01', 'නොහැකිය O', '. O']]
# 100.0
# [['ඊස්රායල් B-ARG1', 'හමුදා I-ARG1', 'නැවත B-return.01', 'ඔවුන්ගේ B-ARG4', 'බැරැක්ක I-ARG4', 'වෙත I-ARG4', 'යා I-return.01', 'යුතුය B-ARGM-MOD', '. O']]
# [['ඊස්රායල් B-ARG1', 'හමුදා I-ARG1', 'නැවත B-return.01', 'ඔවුන්ගේ B-ARG4', 'බැරැක්ක I-ARG4', 'වෙත I-ARG4', 'යා O', 'යුතුය B-ARGM-MOD', '. O']]
# 75.0
# [['ඇයි B-ARG2', 'මේ B-ARG1', '? O', '. O']]
# [['ඇයි B-ARG2', 'මේ B-ARG1', '? O', '. O']]
# 100.0
# [['දැන් B-ARGM-TMP', 'අවශ්\u200dය B-need.01', 'වන්නේ I-need.01', 'නැවත O', 'සිතා O', 'බැලීමකි O', '. O'], ['දැන් B-ARG1', 'අවශ්\u200dය I-ARG1', 'වන්නේ I-ARG1', 'නැවත B-rethink.01', 'සිතා I-rethink.01', 'බැලීමකි I-rethink.01', '. O']]
# [['දැන් B-ARGM-TMP', 'අවශ්\u200dය B-need.01', 'වන්නේ I-need.01', 'නැවත O', 'සිතා O', 'බැලීමකි O', '. O']]
# 50.0
# [['පොසෙල්ට් B-ARGM-DIS', 'මහතා I-ARGM-DIS', ', O', 'විවාදය B-ARG1', 'අවසන් B-close.01', '. O'], ['පොසෙල්ට් B-ARGM-DIS', 'මහතා I-ARGM-DIS', ', O', 'විවාදය B-ARG1', 'අවසන් B-ARG2', '. O']]
# [['පොසෙල්ට් B-ARGM-DIS', 'මහතා I-ARGM-DIS', ', O', 'විවාදය B-ARG1', 'අවසන් B-close.01', '. O'], ['පොසෙල්ට් B-ARGM-DIS', 'මහතා I-ARGM-DIS', ', O', 'විවාදය B-ARG1', 'අවසන් B-ARG2', '. O  B-be.01', '. O']]
# 100.0
# [['දේශගුණික B-ARG1', 'විපර්යාස I-ARG1', 'ගැන I-ARG1', 'අපි B-ARG0', 'කතා B-talk.01', 'කරමු I-talk.01', '. O']]
# [['දේශගුණික B-ARG1', 'විපර්යාස I-ARG1', 'ගැන I-ARG1', 'අපි B-ARG0', 'කතා B-talk.01', 'කරමු I-talk.01', '. O']]
# 100.0
# [['අපට B-ARG2', 'යා I-ARG2', 'යුතු I-ARG2', 'තැන I-ARG2', 'එයයි B-ARG1', '. O'], ['අපට B-ARG0', 'යා B-go.02', 'යුතු O', 'තැන B-ARG4', 'එයයි I-ARG4', '. O']]
# [['අපට B-ARG0', 'යා B-go.02', 'යුතු O', 'තැන B-ARG4', 'එයයි O', '. O']]
# 16.666666666666668
# [['එබැවින් B-ARGM-ADV', 'තර්කය B-ARG1', 'නිසැකවම I-ARGM-ADV', 'කටු I-ARG2', 'සහ I-ARG2', 'සංකීර්ණ I-ARG2', 'ය B-be.01', '. O']]
# [['එබැවින් B-ARGM-ADV', 'තර්කය B-ARG1', 'නිසැකවම I-ARGM-ADV', 'කටු B-ARG2', 'සහ I-ARG2', 'සංකීර්ණ I-ARG2', 'ය B-be.01', '. O']]
# 92.85714285714286
# [['යුරෝපීය B-ARG0', 'කොමිසම I-ARG0', 'එසේ B-ARG1', 'පවසා B-say.01', 'තිබේ I-say.01', '. O']]
# [['යුරෝපීය B-ARG0', 'කොමිසම I-ARG0', 'එසේ B-ARG1', 'පවසා B-say.01', 'තිබේ I-say.01', '. O']]
# 100.0
# [['මේ B-ARG2', 'ආකාරයේ I-ARG2', 'විවේචන I-ARG2', 'සමඟ I-ARG2', 'මම B-ARG0', 'මූලික B-ARGM-MNR', 'වශයෙන් I-ARGM-MNR', 'එකඟ B-disagree.01', 'නොවෙමි I-disagree.01', '. O']]
# [['මේ B-ARG2', 'ආකාරයේ I-ARG2', 'විවේචන I-ARG2', 'සමඟ I-ARG2', 'මම B-ARG0', 'මූලික B-ARGM-MNR', 'වශයෙන් O', 'එකඟ B-disagree.01', 'නොවෙමි I-disagree.01', '. O']]
# 93.75
# [['අපි B-ARG0', 'උත්සාහය B-ARG1', 'කරමු B-make.LV', '. O']]
# [['අපි B-ARG0', 'උත්සාහය B-ARG1', 'කරමු B-make.LV', '. O']]
# 100.00000000000001
# [['යුරෝපයේ B-ARGM-LOC', 'අප B-ARG0', 'බොහෝ B-ARG1', 'අර්බුදවලට I-ARG1', 'මුහුණ B-face.01', 'දී I-face.01', 'සිටිමු I-face.01', '. O']]
# [['යුරෝපයේ B-ARGM-LOC', 'අප B-ARG1', 'බොහෝ B-ARG0', 'අර්බුදවලට I-ARG0', 'මුහුණ B-face.01', 'දී I-face.01', 'සිටිමු I-face.01', '. O']]
# 70.0
# [['ප්\u200dරචණ්ඩත්වය B-ARG1', 'දෙපසම B-ARGM-LOC', 'වහාම B-ARGM-TMP', 'නතර B-cease.01', 'විය I-cease.01', 'යුතුය B-ARGM-MOD', '. O']]
# [['ප්\u200dරචණ්ඩත්වය B-ARG1', 'දෙපසම B-ARGM-LOC', 'වහාම B-ARGM-TMP', 'නතර B-cease.01', 'විය I-cease.01', 'යුතුය B-ARGM-MOD', '. O']]
# 100.0
# [['සංඛ්\u200dයාලේඛන B-ARG1', 'තිබේ B-be.01', '. O']]
# [['සංඛ්\u200dයාලේඛන B-ARG1', 'තිබේ B-be.01', '. O']]
# 100.0
# [['ජනාධිපති B-ARGM-DIS', 'මැඩම් I-ARGM-DIS', ', O', 'මම B-ARG0', 'වාර්තාවට B-ARG1', 'ඡන්දය B-vote.01', 'දුන්නා I-vote.01', '. O']]
# [['ජනාධිපති B-ARGM-DIS', 'මැඩම් I-ARGM-DIS', ', O', 'මම B-ARG0', 'වාර්තාවට B-ARG1', 'ඡන්දය O', 'දුන්නා B-vote.01', '. O']]
# 50.00000000000001
# [['රුසියාවේ B-ARGM-LOC', 'කපාටය B-ARG1', 'නිවා B-turn_off.07', 'දමා B-turn_off.07', 'ඇත O', '. O'], ['රුසියාවේ O', 'කපාටය O', 'නිවා O', 'දමා O', 'ඇත B-have.01', '. O']]
# [['රුසියාවේ O', 'කපාටය O', 'නිවා O', 'දමා O', 'ඇත B-have.01', '. O']]
# 50.0
# [['එවැනි B-ARG1', 'ද්\u200dරව්\u200dය I-ARG1', 'එකතු B-collect.01', 'කිරීම I-collect.01', 'ලාභ O', 'නො O', 'ලැබීමට O', 'පත්වෙමින් O', 'පවතී O', '. O'], ['එවැනි B-ARG1', 'ද්\u200dරව්\u200dය I-ARG1', 'එකතු I-ARG1', 'කිරීම I-ARG1', 'ලාභ B-ARG2', 'නො I-ARG2', 'ලැබීමට I-ARG2', 'පත්වෙමින් B-become.01', 'පවතී I-become.01', '. O'], ['එවැනි O', 'ද්\u200dරව්\u200dය O', 'එකතු O', 'කිරීම O', 'ලාභ O', 'නො O', 'ලැබීමට O', 'පත්වෙමින් O', 'පවතී B-be.03', '. O']]
# [['එවැනි B-ARG1', 'ද්\u200dරව්\u200dය I-ARG1', 'එකතු B-collect.01', 'කිරීම I-collect.01', 'ලාභ O', 'නො O', 'ලැබීමට O', 'පත්වෙමින් O', 'පවතී O', '. O'], ['එවැනි B-ARG1', 'ද්\u200dරව්\u200dය I-ARG1', 'එකතු I-ARG1', 'කිරීම I-ARG1', 'ලාභ O', 'නො O', 'ලැබීමට O', 'පත්වෙමින් B-become.01', 'පවතී O', '. O'], ['එවැනි O', 'ද්\u200dරව්\u200dය O', 'එකතු O', 'කිරීම O', 'ලාභ O', 'නො O', 'ලැබීමට O', 'පත්වෙමින් O', 'පවතී B-be.03', '. O']]
# 85.41666666666669
# [['නැනෝ B-ARG1', 'අමුද්\u200dරව්\u200dය I-ARG1', 'ලේබල් I-ARG1', 'කිරීමට I-ARG1', 'ද B-ARGM-DIS', 'අපි B-ARG0', 'සහාය B-support.01', 'දෙන්නෙමු I-support.01', '. O']]
# [['නැනෝ B-ARG1', 'අමුද්\u200dරව්\u200dය I-ARG1', 'ලේබල් I-ARG1', 'කිරීමට O', 'ද B-ARGM-MOD', 'අපි B-ARG0', 'සහාය B-support.01', 'දෙන්නෙමු I-support.01', '. O']]
# 85.71428571428571
# [['අප B-ARG1', 'මුහුණ I-ARG1', 'දෙන I-ARG1', 'ගැටලු I-ARG1', 'යුරෝපීය B-ARG2', 'ය B-be.01', '. O']]
# [['අප B-ARG1', 'මුහුණ I-ARG1', 'දෙන I-ARG1', 'ගැටලු I-ARG1', 'යුරෝපීය B-ARG2', 'ය B-be.01', '. O']]
# 100.0
# [['කෙසේ B-ARGM-DIS', 'වෙතත් B-ARGM-DIS', ', O', 'මට B-ARG0', 'අදහස් B-ARG1', 'දැක්වීම් I-ARG1', 'කිහිපයක් I-ARG1', 'තිබේ B-have.03', '. O']]
# [['කෙසේ B-ARGM-DIS', 'වෙතත් O', ', O', 'මට B-ARG0', 'අදහස් O', 'දැක්වීම් O', 'කිහිපයක් B-ARG1', 'තිබේ B-have.03', '. O']]
# 75.0
# [['අපි B-ARG0', 'දැන් B-ARGM-TMP', 'ඡන්ද B-ARG1', 'කාලය I-ARG1', 'සමඟ I-ARG1', 'ඉදිරියට B-continue.01', 'යමු I-continue.01', '. O']]
# [['අපි B-ARG0', 'දැන් B-ARGM-TMP', 'ඡන්ද B-ARG1', 'කාලය I-ARG1', 'සමඟ I-ARG1', 'ඉදිරියට B-continue.01', 'යමු I-continue.01', '. O']]
# 100.0
# [['අමතර B-ARG0', 'CO2 I-ARG0', 'වැඩි B-ARG1', 'බලපෑමක් I-ARG1', 'ඇති B-have.03', 'නො I-ARG1', 'කරනු B-ARGM-MOD', 'ඇත O', '. O']]
# [['අමතර B-ARG0', 'CO2 I-ARG0', 'වැඩි B-ARG1', 'බලපෑමක් I-ARG1', 'ඇති B-have.03', 'නො I-ARG1', 'කරනු B-ARGM-MOD', 'ඇත O', '. O']]
# 100.0
# [['සංවාදයට B-ARG1', 'ප්\u200dරවේශ I-ARG1', 'වීම I-ARG1', 'සාධාරණ B-ARG2', 'විය B-be.01', 'යුතුය B-ARGM-MOD', '. O']]
# [['සංවාදයට B-ARG1', 'ප්\u200dරවේශ I-ARG1', 'වීම I-ARG1', 'සාධාරණ B-ARG2', 'විය B-be.01', 'යුතුය B-ARGM-MOD', '. O']]
# 100.0
# [['එබැවින් B-ARGM-DIS', 'මම B-ARG0', 'මෙම B-ARG1', 'වාර්තාවට I-ARG1', 'පක්ෂව I-ARG1', 'ඡන්දය B-vote.01', 'ප්\u200dරකාශ I-vote.01', 'කළෙමි I-vote.01', '. O']]
# [['එබැවින් B-ARGM-DIS', 'මම B-ARG0', 'මෙම B-ARG1', 'වාර්තාවට I-ARG1', 'පක්ෂව I-ARG1', 'ඡන්දය B-vote.01', 'ප්\u200dරකාශ O', 'කළෙමි O', '. O']]
# 66.66666666666667
# [['ඔබ B-ARG0', 'දන්නා B-know.06', 'පරිදි I-know.06', 'තත්වය O', 'බරපතල O', 'ය O', '. O'], ['ඔබ B-ARGM-ADV', 'දන්නා I-ARGM-ADV', 'පරිදි I-ARGM-ADV', 'තත්වය B-ARG1', 'බරපතල B-ARG2', 'ය B-be.01', '. O']]
# [['ඔබ B-ARG0', 'දන්නා B-know.06', 'පරිදි O', 'තත්වය O', 'බරපතල O', 'ය O', '. O'], ['ඔබ B-ARGM-ADV', 'දන්නා I-ARGM-ADV', 'පරිදි I-ARGM-ADV', 'තත්වය B-ARG1', 'බරපතල B-ARG2', 'ය B-be.01', '. O']]
# 87.49999999999999
# [['වැඩි B-ARG1', 'වැඩියෙන් I-ARG1', 'හුදෙකලා I-ARG1', 'බවක්  I-ARG1', 'දැනීමට B-feel.01', 'අපට B-ARG0', 'අයිතියක් O', 'ඇත O', '. O'], ['වැඩි B-ARG2', 'වැඩියෙන් I-ARG2', 'හුදෙකලා I-ARG2', 'බවක් I-ARG2', 'දැනීමට I-ARG2', 'අපට B-ARG1', 'අයිතියක් I-ARG2', 'ඇත B-be.03', '. O'], ['වැඩි B-ARG1', 'වැඩියෙන් I-ARG1', 'හුදෙකලා I-ARG1', 'බවක් I-ARG1', 'දැනීමට I-ARG1', 'අපට B-ARG2', 'අයිතියක් B-entitle.01', 'ඇත I-entitle.01', '. O']]
# [['වැඩි O', 'වැඩියෙන් B-ARG1', 'හුදෙකලා I-ARG1', 'බවක් O', 'දැනීමට B-feel.01', 'අපට B-ARG0', 'අයිතියක් O', 'ඇත O', '. O'], ['වැඩි O', 'වැඩියෙන් B-ARG2', 'හුදෙකලා I-ARG2', 'බවක් O', 'දැනීමට I-ARG2', 'අපට B-ARG1', 'අයිතියක් I-ARG2', 'ඇත B-be.03', '. O']]
# 54.166666666666664
# [['ඒ B-ARG0', 'කියන්නේ B-mean.01', 'අපනයන B-ARG1', 'මුදල් I-ARG1', 'ආපසු I-ARG1', 'ගෙවීම I-ARG1', 'ඉවත් I-ARG1', 'කිරීම I-ARG1', '. O'], ['ඒ O', 'කියන්නේ O', 'අපනයන  B-ARG1', 'මුදල් I-ARG1', 'ආපසු I-ARG1', 'ගෙවීම I-ARG1', 'ඉවත් B.dismantle.01', 'කිරීම I.dismantle.01', '. O']]
# [['ඒ B-ARG0', 'කියන්නේ B-mean.01', 'අපනයන B-ARG1', 'මුදල් O', 'ආපසු O', 'ගෙවීම O', 'ඉවත් O', 'කිරීම O', '. O']]
# 68.75
# [['බීජිනය B-ARG0', 'විසින් I-ARG0', 'ගනු B-take.01', 'ලැබූ I-take.01', 'රේඛාව B-ARG1', 'එයයි O', '. O'], ['බීජිනය B-ARG1', 'විසින් I-ARG1', 'ගනු I-ARG1', 'ලැබූ I-ARG1', 'රේඛාව I-ARG1', 'එයයි B-ARG0', '. O']]
# [['බීජිනය B-ARG0', 'විසින් I-ARG0', 'ගනු B-take.01', 'ලැබූ I-take.01', 'රේඛාව B-ARG1', 'එයයි O', '. O']]
# 100.0
# [['මගේ O', 'දෙවන O', 'ප්\u200dරශ්නය O', 'පහත B-follow.04', 'පරිදි O', 'වේ O', '. O'], ['මගේ B-ARG1', 'දෙවන I-ARG1', 'ප්\u200dරශ්නය I-ARG1', 'පහත B-ARG2', 'පරිදි I-ARG2', 'වේ B-be.01', '. O']]
# [['මගේ O', 'දෙවන O', 'ප්\u200dරශ්නය O', 'පහත B-follow.04', 'පරිදි O', 'වේ O', '. O'], ['මගේ B-ARG1', 'දෙවන I-ARG1', 'ප්\u200dරශ්නය I-ARG1', 'පහත B-ARG2', 'පරිදි I-ARG2', 'වේ B-be.01', '. O']]
# 100.0
# [['අපි B-ARG0', 'මේ B-ARGM-EXT', 'පාර I-ARGM-EXT', 'දිගේ I-ARGM-EXT', 'තවත් I-ARGM-EXT', 'ඉදිරියට I-ARGM-EXT', 'යා B-go.02', 'යුතුවෙමු I-go.02', '. O']]
# [['අපි B-ARG0', 'මේ B-ARGM-EXT', 'පාර I-ARGM-EXT', 'දිගේ I-ARGM-EXT', 'තවත් I-ARGM-EXT', 'ඉදිරියට I-ARGM-EXT', 'යා B-go.02', 'යුතුවෙමු I-go.02', '. O']]
# 100.0
# [['එම B-ARG1', 'කවුන්සිලය I-ARG1', 'තුළ I-ARG1', 'යුරෝපීය I-ARG1', 'ස්ථාවරය I-ARG1', 'තීරණාත්මක B-ARG2', 'ය B-be.01', '. O']]
# [['එම B-ARG1', 'කවුන්සිලය I-ARG1', 'තුළ I-ARG1', 'යුරෝපීය I-ARG1', 'ස්ථාවරය I-ARG1', 'තීරණාත්මක B-ARG2', 'ය B-be.01', '. O']]
# 100.0
# [['කෙසේ B-ARGM-DIS', 'වෙතත් B-ARGM-DIS', 'අප B-ARG0', 'කළ B-do.02', 'යුත්තේ B-ARGM-MOD', 'කුමක්ද B-ARG1', '? O', '. O']]
# [['කෙසේ B-ARGM-DIS', 'වෙතත් O', 'අප B-ARG0', 'කළ B-do.02', 'යුත්තේ B-ARGM-MOD', 'කුමක්ද B-ARG1', '? O', '. O']]
# 92.85714285714283
# [['කොමිෂන් B-ARG1', 'සභාවේ I-ARG1', 'ජැස්මින් I-ARG1', 'වැඩසටහන I-ARG1', 'ද B-ARGM-ADV', 'අපි B-ARG0', 'සාදරයෙන් B-welcome.01', 'පිළිගනිමු I-welcome.01', '. O']]
# [['කොමිෂන් B-ARG1', 'සභාවේ I-ARG1', 'ජැස්මින් I-ARG1', 'වැඩසටහන O', 'ද B-ARGM-ADV', 'අපි B-ARG0', 'සාදරයෙන් B-welcome.01', 'පිළිගනිමු O', '. O']]
# 67.85714285714286
# [['දැන් B-ARGM-TMP', 'අපි B-ARG0', 'තවදුරටත් B-ARGM-EXT', 'ඉදිරියට I-ARGM-EXT', 'යමු B-go.02', '. O']]
# [['දැන් B-ARGM-TMP', 'අපි B-ARG0', 'තවදුරටත් B-ARGM-EXT', 'ඉදිරියට O', 'යමු B-go.02', '. O']]
# 90.0
# [['මම B-ARG1', 'හැම B-ARGM-TMP', 'විටම I-ARGM-TMP', 'එයට B-ARG2', 'පක්ෂව I-ARG2', 'සිටිමි B-be.01', '. O']]
# [['මම B-ARG1', 'හැම O', 'විටම B-ARGM-TMP', 'එයට B-ARG2', 'පක්ෂව I-ARG2', 'සිටිමි B-be.01', '. O']]
# 83.33333333333333
# [['සෑම B-ARGM-LOC', 'තැනකම I-ARGM-LOC', 'සොයාගත B-find.01', 'හැකි O', 'හොඳ B-ARG1', 'උදාහරණ I-ARG1', 'තිබේ O', '. O'], ['සෑම B-ARG1', 'තැනකම I-ARG1', 'සොයාගත I-ARG1', 'හැකි I-ARG1', 'හොඳ I-ARG1', 'උදාහරණ I-ARG1', 'තිබේ B-be.02', '. O']]
# [['සෑම O', 'තැනකම B-ARGM-LOC', 'සොයාගත B-find.01', 'හැකි O', 'හොඳ B-ARG1', 'උදාහරණ I-ARG1', 'තිබේ O', '. O'], ['සෑම O', 'තැනකම B-ARG1', 'සොයාගත I-ARG1', 'හැකි O', 'හොඳ I-ARG1', 'උදාහරණ I-ARG1', 'තිබේ B-be.02', '. O']]
# 82.14285714285712
# [['IATA B-ARG0', 'විසින් I-ARG0', 'අද I-ARG0', 'සපයන I-ARG0', 'ලද I-ARG0', 'දත්ත I-ARG0', 'කනස්සල්ලට B-worry.02', 'කරුණකි O', '. O'], ['IATA B-ARG0', 'විසින් I-ARG0', 'අද B-ARGM-TMP', 'සපයන B-supply.01', 'ලද I-supply.01', 'දත්ත I-ARG1', 'කනස්සල්ලට O', 'කරුණකි O', '. O']]
# [['IATA B-ARG0', 'විසින් I-ARG0', 'අද I-ARG0', 'සපයන I-ARG0', 'ලද I-ARG0', 'දත්ත I-ARG0', 'කනස්සල්ලට B-worry.02', 'කරුණකි O', '. O']]
# 50.0
# [['එය B-ARG1', 'හොඳින් B-ARG2', 'සූදානම් I-ARG2', 'බව B-be.01', 'පෙනේ O', '. O'], ['එය O', 'හොඳින් B-ARG1', 'සූදානම් I-ARG1', 'බව I-ARG1', 'පෙනේ B-seem.01', '. O']]
# [['එය B-ARG1', 'හොඳින් B-ARG2', 'සූදානම් I-ARG2', 'බව B-be.01', 'පෙනේ O', '. O'], ['එය O', 'හොඳින් B-ARG1', 'සූදානම් I-ARG1', 'බව I-ARG1', 'පෙනේ B-seem.01', '. O']]
# 100.0
# [['එබැවින් B-ARGM-DIS', 'පාර්ලිමේන්තුව B-ARG0', 'කොමිසමෙන් B-ARG2', 'ඉල්ලා B-ask.02', 'සිටින්නේ I-ask.02', 'කුමක්ද B-ARG1', '? O', '. O']]
# [['එබැවින් B-ARGM-DIS', 'පාර්ලිමේන්තුව B-ARG0', 'කොමිසමෙන් B-ARG2', 'ඉල්ලා B-ask.02', 'සිටින්නේ I-ask.02', 'කුමක්ද B-ARG1', '? O', '. O']]
# 99.99999999999999
# [['එය B-ARG1', 'අත්\u200dයවශ්\u200dයයි B-ARG2', '. O']]
# [['එය B-ARG1', 'අත්\u200dයවශ්\u200dයයි B-ARG2', '. O']]
# 100.0
# [['මෙම B-ARG2', 'අවස්ථාවෙන් I-ARG2', 'අප B-ARG0', 'ප්\u200dරයෝජන B-ARG1', 'ගත B-take.01', 'යුතුය B-ARGM-MOD', '. O']]
# [['මෙම B-ARG2', 'අවස්ථාවෙන් I-ARG2', 'අප B-ARG0', 'ප්\u200dරයෝජන B-ARG1', 'ගත B-take.01', 'යුතුය B-ARGM-MOD', '. O']]
# 100.0
# [['එය B-ARG1', 'ගැටලුව B-ARG2', 'නො B-ARGM-NEG', 'වේ B-be.01', '. O']]
# [['එය B-ARG1', 'ගැටලුව B-ARG2', 'නො B-ARGM-NEG', 'වේ B-be.01', '. O']]
# 100.0
# [['කොමිසමේ B-ARG1', 'යෝජනාව I-ARG1', 'ඉතා B-ARG2', 'දුර්වල I-ARG2', 'ය B-be.01', '. O']]
# [['කොමිසමේ B-ARG1', 'යෝජනාව I-ARG1', 'ඉතා B-ARG2', 'දුර්වල I-ARG2', 'ය B-be.01', '. O']]
# 100.0
# [['එය B-ARG1', 'ටිකක් B-ARG2', 'අනතුරුදායක I-ARG2', 'ය B-be.01', '. O']]
# [['එය B-ARG1', 'ටිකක් B-ARG2', 'අනතුරුදායක I-ARG2', 'ය B-be.01', '. O']]
# 100.0
# [['IPPC B-ARG0', 'කර්මාන්තයේ B-ARG1', 'සෑම I-ARG1', 'අංශයකටම I-ARG1', 'පාහේ I-ARG1', 'බලපායි B-affect.01', '. O']]
# [['IPPC B-ARG0', 'කර්මාන්තයේ B-ARG1', 'සෑම I-ARG1', 'අංශයකටම I-ARG1', 'පාහේ I-ARG1', 'බලපායි B-affect.01', '. O']]
# 100.0
# [['වැඩි B-ARG0', 'ඒකාග්\u200dරතාවයක් I-ARG0', 'නොවරදවාම B-ARGM-ADV', 'අදහස් B-mean.01', 'කරන්නේ I-mean.01', 'වැඩි B-ARG1', 'මැදිහත් I-ARG1', 'වීමක් I-ARG1', '. O']]
# [['වැඩි B-ARG0', 'ඒකාග්\u200dරතාවයක් O', 'නොවරදවාම B-ARGM-ADV', 'අදහස් B-mean.01', 'කරන්නේ I-mean.01', 'වැඩි B-ARG1', 'මැදිහත් O', 'වීමක් O', '. O']]
# 78.57142857142856
# [['කොමසාරිස් B-ARGM-DIS', ', O', 'මම B-ARG0', 'ඔබ B-ARG1', 'සමඟ I-ARG1', 'සම්පූර්ණයෙන්ම B-ARGM-EXT', 'එකඟ B-disagree.01', 'නොවෙමි I-disagree.01', '. O']]
# [['කොමසාරිස් B-ARGM-DIS', ', O', 'මම B-ARG0', 'ඔබ B-ARG1', 'සමඟ I-ARG1', 'සම්පූර්ණයෙන්ම O', 'එකඟ B-disagree.01', 'නොවෙමි I-disagree.01', '. O']]
# 92.85714285714286
# [['නිශ්චිත B-ARG1', 'වීමට I-ARG1', 'මට I-ARG1', 'ඉඩ B-allow.01', 'දෙන්න I-allow.01', '. O']]
# [['නිශ්චිත B-ARG1', 'වීමට I-ARG1', 'මට I-ARG1', 'ඉඩ B-allow.01', 'දෙන්න I-allow.01', '. O']]
# 100.0
# [['ව්\u200dයවස්ථාදායකයන් B-ARGM-PRD', 'වශයෙන් I-ARGM-PRD', 'දරුවන්ට B-ARG0', 'අපගේ B-ARG1', 'රැකවරණය I-ARG1', 'හා I-ARG1', 'ආරක්ෂාව I-ARG1', 'අවශ්\u200dයයි B-need.01', '. O']]
# [['ව්\u200dයවස්ථාදායකයන් B-ARGM-PRD', 'වශයෙන් I-ARGM-PRD', 'දරුවන්ට B-ARG0', 'අපගේ B-ARG1', 'රැකවරණය I-ARG1', 'හා I-ARG1', 'ආරක්ෂාව I-ARG1', 'අවශ්\u200dයයි B-need.01', '. O']]
# 100.0
# [['ඔවුන් B-ARG1', 'එම B-ARG2', 'ප්\u200dරතිපත්තියේ I-ARG2', 'හවුල්කරුවන් I-ARG2', 'වී B-be.01', 'ඇත O', '. O']]
# [['ඔවුන් O', 'එම O', 'ප්\u200dරතිපත්තියේ O', 'හවුල්කරුවන් O', 'වී O', 'ඇත B-have.01', '. O']]
# 0
# [['කෙසේ B-ARGM-DIS', 'වෙතත් I-ARGM-DIS', 'ඔවුන් B-ARG1', 'කුමන B-ARG2', 'ආකාරයේ I-ARG2', 'රැකියා I-ARG2', 'ද O', '? O', '. O']]
# [['කෙසේ B-ARGM-DIS', 'වෙතත් O', 'ඔවුන් B-ARG1', 'කුමන B-ARG2', 'ආකාරයේ I-ARG2', 'රැකියා I-ARG2', 'ද O', '? O', '. O']]
# 88.8888888888889
# [['වර්තමාන B-ARG2', 'අර්බුදයෙන් I-ARG2', 'අප B-ARG0', 'ඉගෙන B-learn.01', 'ගත I-learn.01', 'යුතුය B-ARGM-MOD', '. O']]
# [['වර්තමාන B-ARG2', 'අර්බුදයෙන් I-ARG2', 'අප B-ARG0', 'ඉගෙන B-learn.01', 'ගත I-learn.01', 'යුතුය B-ARGM-MOD', '. O']]
# 100.0
# [['අපි B-ARG0', 'සාකච්ඡාවෙන් B-ARGM-EXT', 'ඔබ්බට I-ARGM-EXT', 'යමු B-go.02', '. O']]
# [['අපි B-ARG0', 'සාකච්ඡාවෙන් B-ARGM-EXT', 'ඔබ්බට I-ARGM-EXT', 'යමු B-go.02', '. O']]
# 100.0
# [['මම B-ARG0', 'මෙතන B-ARGM-LOC', 'නවතිනවා B-stop.01', '. O']]
# [['මම B-ARG0', 'මෙතන B-ARGM-LOC', 'නවතිනවා B-stop.01', '. O']]
# 100.00000000000001
# [['අපි B-ARG0', 'මේ B-ARG1', 'සම්බන්ධයෙන් I-ARG1', 'ඉක්මනින් B-ARGM-MNR', 'ක්\u200dරියා B-act.02', 'කළ I-act.02', 'යුතුයි O', '. O'], ['අපි B-ARG0', 'මේ B-ARG1', 'සම්බන්ධයෙන් I-ARG1', 'ඉක්මනින් I-ARG1', 'ක්\u200dරියා I-ARG1', 'කළ I-ARG1', 'යුතුයි B-need.01', '. O']]
# [['අපි B-ARG0', 'මේ B-ARG1', 'සම්බන්ධයෙන් I-ARG1', 'ඉක්මනින් B-ARGM-MNR', 'ක්\u200dරියා B-act.02', 'කළ I-act.02', 'යුතුයි O', '. O'], ['අපි B-ARG0', 'මේ B-ARG1', 'සම්බන්ධයෙන් I-ARG1', 'ඉක්මනින් I-ARG1', 'ක්\u200dරියා I-ARG1', 'කළ I-ARG1', 'යුතුයි B-need.01', '. O']]
# 99.99999999999999
# [['කෙසේ B-ARGM-DIS', 'වෙතත් I-ARGM-DIS', ', O', 'එය B-ARG1', 'අත්\u200dයවශ්\u200dය B-ARG2', 'කෙටිකාලීන I-ARG2', 'පියවරක් I-ARG2', 'විය B-be.01', '. O']]
# [['කෙසේ B-ARGM-DIS', 'වෙතත් O', ', O', 'එය B-ARG1', 'අත්\u200dයවශ්\u200dය B-ARG2', 'කෙටිකාලීන I-ARG2', 'පියවරක් I-ARG2', 'විය B-be.01', '. O']]
# 93.75
# [['මේ B-ARG1', 'සියල්ලෙහි I-ARG1', 'රුසියාවේ I-ARG1', 'කොටස I-ARG1', 'කුමක්ද B-ARG2', '? O', '. O']]
# [['මේ B-ARG1', 'සියල්ලෙහි I-ARG1', 'රුසියාවේ I-ARG1', 'කොටස I-ARG1', 'කුමක්ද B-ARG2', '? O', '. O']]
# 100.00000000000001
# [['නව B-ARG1', 'තාක්\u200dෂණය I-ARG1', 'සඳහා I-ARG1', 'ආයෝජනය I-ARG1', 'කිරීම I-ARG1', 'මෙයට B-ARG2', 'ඇතුළත් B-include.01', 'ය O', '. O']]
# [['නව B-ARG1', 'තාක්\u200dෂණය I-ARG1', 'සඳහා I-ARG1', 'ආයෝජනය I-ARG1', 'කිරීම I-ARG1', 'මෙයට B-ARG2', 'ඇතුළත් B-include.01', 'ය O', '. O']]
# 100.0
# [['සටන් B-ARG1', 'විරාමයක් I-ARG1', 'යනු B-be.01', 'අපට B-ARG2', 'අවශ්\u200dය I-ARG2', 'දෙයයි I-ARG2', '! O', '. O'], ['සටන් O', 'විරාමයක් O', 'යනු O', 'අපට B-ARG0', 'අවශ්\u200dය B-want.01', 'දෙයයි B-ARG1', '! O', '. O']]
# [['සටන් O', 'විරාමයක් B-ARG1', 'යනු B-be.01', 'අපට B-ARG2', 'අවශ්\u200dය I-ARG2', 'දෙයයි I-ARG2', '! O', '. O'], ['සටන් O', 'විරාමයක් O', 'යනු O', 'අපට B-ARG0', 'අවශ්\u200dය B-want.01', 'දෙයයි B-ARG1', '! O', '. O']]
# 92.85714285714285
# [['මෙය B-ARG1', 'නැවැත්විය B-stop.01', 'යුතුය B-ARGM-MOD', '. O']]
# [['මෙය B-ARG1', 'නැවැත්විය B-stop.01', 'යුතුය B-ARGM-MOD', '. O']]
# 100.00000000000001
# [['එබැවින් O', 'ජනතාව O', 'තමන්ට B-ARG0', 'අවශ්\u200dය B-want.01', 'දේ B-ARG1', 'දැන O', 'සිටිය O', 'යුතුය O', '. O'], ['එබැවින් B-ARGM-DIS', 'ජනතාව B-ARG0', 'තමන්ට B-ARG1', 'අවශ්\u200dය I-ARG1', 'දේ I-ARG1', 'දැන B-know.01', 'සිටිය I-know.01', 'යුතුය B-ARGM-MOD', '. O']]
# [['එබැවින් O', 'ජනතාව O', 'තමන්ට B-ARG0', 'අවශ්\u200dය B-want.01', 'දේ B-ARG1', 'දැන O', 'සිටිය O', 'යුතුය O', '. O'], ['එබැවින් B-ARGM-DIS', 'ජනතාව B-ARG0', 'තමන්ට B-ARG1', 'අවශ්\u200dය I-ARG1', 'දේ I-ARG1', 'දැන B-know.01', 'සිටිය I-know.01', 'යුතුය B-ARGM-MOD', '. O']]
# 99.99999999999999
# [['එම B-ARG1', 'ප්\u200dරවාදය I-ARG1', 'සම්පූර්ණයෙන්ම B-ARG2', 'වැරදිය I-ARG2', '. O']]
# [['එම B-ARG1', 'ප්\u200dරවාදය I-ARG1', 'සම්පූර්ණයෙන්ම B-ARG2', 'වැරදිය I-ARG2', '. O  B-be.01', '. O']]
# 100.0
# [['පළපුරුදු B-ARG2', 'සාගතයෙන් I-ARG2', 'මා B-ARG1', 'පැමිණි B-come.01', 'රට I-ARG1', '. O']]
# [['පළපුරුදු B-ARG2', 'සාගතයෙන් I-ARG2', 'මා B-ARG1', 'පැමිණි B-come.01', 'රට I-ARG1', '. O']]
# 100.0
# [['මෙම B-ARG1', 'ප්\u200dරතිපත්තිය I-ARG1', 'අසාර්ථක B-fail.01', 'විය I-fail.01', '. O']]
# [['මෙම B-ARG1', 'ප්\u200dරතිපත්තිය I-ARG1', 'අසාර්ථක B-fail.01', 'විය I-fail.01', '. O']]
# 100.00000000000001
# [['මගේ B-ARG1', 'ප්\u200dරශ්නය I-ARG1', 'පහත B-ARG2', 'පරිදි I-ARG2', 'වේ B-be.01', '. O']]
# [['මගේ O', 'ප්\u200dරශ්නය O', 'පහත B-follow.04', 'පරිදි O', 'වේ O', '. O'], ['මගේ B-ARG1', 'ප්\u200dරශ්නය I-ARG1', 'පහත B-ARG2', 'පරිදි I-ARG2', 'වේ B-be.01', '. O']]
# 100.0
# [['මෙය B-ARG1', 'ලබන B-ARGM-TMP', 'වසරේ I-ARGM-TMP', 'අපගේ B-ARG2', 'විශාලතම I-ARG2', 'අභියෝගය I-ARG2', 'වනු B-be.01', 'ඇත B-ARGM-MOD', '. O']]
# [['මෙය B-ARG1', 'ලබන B-ARGM-TMP', 'වසරේ I-ARGM-TMP', 'අපගේ B-ARG2', 'විශාලතම I-ARG2', 'අභියෝගය I-ARG2', 'වනු B-be.01', 'ඇත B-ARGM-MOD', '. O']]
# 100.0
# [['අපටත් B-ARG0', 'එය B-ARG1', 'අවශ්\u200dය B-want.01', 'නැත B-ARGM-NEG', '. O']]
# [['අපටත් B-ARG0', 'එය B-ARG1', 'අවශ්\u200dය B-want.01', 'නැත B-ARGM-NEG', '. O']]
# 100.0
# [['තායිලන්තය B-ARG0', 'ද B-ARGM-DIS', 'වගකීම B-ARG1', 'ගත B-take.01', 'යුතුය B-ARGM-MOD', '. O']]
# [['තායිලන්තය B-ARG0', 'ද B-ARGM-DIS', 'වගකීම B-ARG1', 'ගත B-take.01', 'යුතුය B-ARGM-MOD', '. O']]
# 100.0
# [['මම B-ARG0', 'කොමසාරිස්වරයාට B-ARG1', 'ස්තූති B-thank.01', 'කිරීමට I-thank.01', 'කැමතියි O', '. O'], ['මම B-ARG0', 'කොමසාරිස්වරයාට B-ARG2', 'ස්තූති I-ARG2', 'කිරීමට I-ARG2', 'කැමතියි B-like.02', '. O']]
# [['මම B-ARG0', 'කොමසාරිස්වරයාට B-ARG1', 'ස්තූති B-thank.01', 'කිරීමට O', 'කැමතියි O', '. O']]
# 37.5
# [['මේ B-ARG0', 'සඳහා I-ARG0', 'අන්තර් B-ARG1', 'සම්බන්ධතා I-ARG1', 'අවශ්\u200dය B-require.01', 'වේ I-require.01', '. O']]
# [['මේ B-ARG0', 'සඳහා O', 'අන්තර් O', 'සම්බන්ධතා O', 'අවශ්\u200dය B-require.01', 'වේ I-require.01', '. O']]
# 70.0
# [['සංවර්ධන B-ARG1', 'ආධාර I-ARG1', 'ප්\u200dරවර්ධනය I-ARG1', 'කිරීමේ I-ARG1', 'ඕනෑම I-ARG1', 'උත්සාහයකට I-ARG1', 'මම B-ARG0', 'සහාය B-support.01', 'දෙමි I-support.01', '. O']]
# [['සංවර්ධන B-ARG1', 'ආධාර I-ARG1', 'ප්\u200dරවර්ධනය I-ARG1', 'කිරීමේ I-ARG1', 'ඕනෑම I-ARG1', 'උත්සාහයකට I-ARG1', 'මම B-ARG0', 'සහාය B-support.01', 'දෙමි I-support.01', '. O']]
# 100.0
# [['දෙවනුව O', ', O', 'තාක්ෂණික I-ARG1', 'අපක්ෂපාතීත්වය I-ARG1', 'සහතික B-guarantee.01', 'කළ I-guarantee.01', 'හැක්කේ B-ARGM-MOD', 'කෙසේද B-ARGM-MNR', '? O', '. O']]
# [['දෙවනුව B-ARG1', ', I-ARG1', 'තාක්ෂණික I-ARG1', 'අපක්ෂපාතීත්වය I-ARG1', 'සහතික B-guarantee.01', 'කළ I-guarantee.01', 'හැක්කේ B-ARGM-MOD', 'කෙසේද B-ARGM-MNR', '? O', '. O']]
# 87.5
# [['ගෝලීය B-ARG0', 'මූල්\u200dය I-ARG0', 'අර්බුදය I-ARG0', 'ලැට්වියාවට B-ARG1', 'ද B-ARGM-ADV', 'පහර B-hit.01', 'දී I-hit.01', 'තිබේ I-hit.01', '. O']]
# [['ගෝලීය B-ARG0', 'මූල්\u200dය I-ARG0', 'අර්බුදය I-ARG0', 'ලැට්වියාවට O', 'ද B-ARGM-ADV', 'පහර B-hit.01', 'දී I-hit.01', 'තිබේ I-hit.01', '. O']]
# 91.66666666666667
# [['මම B-ARG0', 'හිතන්නේ B-think.01', 'අපි B-ARG1', 'එය I-ARG1', 'මතක I-ARG1', 'තබා I-ARG1', 'ගත I-ARG1', 'යුතුයි I-ARG1', '. O'], ['මම O', 'හිතන්නේ O', 'අපි B-ARG0', 'එය B-ARG1', 'මතක B-remember.01', 'තබා O', 'ගත O', 'යුතුයි B-ARGM-MOD', '. O']]
# [['මම B-ARG0', 'හිතන්නේ B-think.01', 'අපි B-ARG1', 'එය I-ARG1', 'මතක I-ARG1', 'තබා O', 'ගත O', 'යුතුයි I-ARG1', '. O'], ['මම O', 'හිතන්නේ O', 'අපි B-ARG0', 'එය B-ARG1', 'මතක B-remember.01', 'තබා O', 'ගත O', 'යුතුයි B-ARGM-MOD', '. O']]
# 93.75
# [['යුරෝපයේ B-ARGM-LOC', 'එය B-ARG1', 'අවසර B-permit.01', 'නැත B-ARGM-NEG', '. O']]
# [['යුරෝපයේ B-ARGM-LOC', 'එය B-ARG1', 'අවසර B-permit.01', 'නැත B-ARGM-NEG', '. O'], ['යුරෝපයේ O', 'එය O', 'අවසර O', 'නැත O', '. O  B-be.03', '. O']]
# 100.0
# [['මම B-ARG0', 'හිතන්නේ B-think.01', 'මෙය B-ARG1', 'අසාධාරණයි I-ARG1', '. O']]
# [['මම B-ARG0', 'හිතන්නේ B-think.01', 'මෙය B-ARG1', 'අසාධාරණයි I-ARG1', '. O']]
# 100.0
# [['කෙසේ B-ARGM-ADV', 'වෙතත් I-ARGM-ADV', ', O', 'ඔහුගේ B-ARG1', 'සහාය B-support.01', 'සඳහා O', '. O']]
# [['කෙසේ B-ARGM-ADV', 'වෙතත් O', ', O', 'ඔහුගේ B-ARG1', 'සහාය B-support.01', 'සඳහා O', '. O']]
# 91.66666666666666
# [['පෙර B-ARG0', 'කථිකයා I-ARG0', 'පැවසුවේ B-say.01', 'එය B-ARG1', 'කළ I-ARG1', 'නොහැකි I-ARG1', 'බවයි I-ARG1', '. O'], ['පෙර O', 'කථිකයා O', 'පැවසුවේ O', 'එය B-ARGI', 'කළ B-ARG2', 'නොහැකි I-ARG2', 'බවයි B-be.01', '. O']]
# [['පෙර B-ARG0', 'කථිකයා I-ARG0', 'පැවසුවේ B-say.01', 'එය B-ARG1', 'කළ O', 'නොහැකි I-ARG1', 'බවයි I-ARG1', '. O'], ['පෙර O', 'කථිකයා O', 'පැවසුවේ O', 'එය O', 'කළ O', 'නොහැකි B-ARG2', 'බවයි B-be.01', '. O']]
# 85.7142857142857
# [['කෘමිනාශක B-ARG0', 'DNA B-ARG1', 'විකෘති B-disrupt.01', 'කළ I-disrupt.01', 'හැකි B-ARGM-MOD', 'බව I-ARGM-MOD', 'අපට O', 'කියනු O', 'ලැබේ O', '. O'], ['කෘමිනාශක O', 'DNA O', 'විකෘති O', 'කළ O', 'හැකි O', 'බව B-be.03', 'අපට O', 'කියනු O', 'ලැබේ O', '. O'], ['කෘමිනාශක B-ARG1', 'DNA I-ARG1', 'විකෘති I-ARG1', 'කළ I-ARG1', 'හැකි I-ARG1', 'බව I-ARG1', 'අපට B-ARG2', 'කියනු B-tell.01', 'ලැබේ I-tell.01', '. O']]
# [['කෘමිනාශක B-ARG0', 'DNA B-ARG1', 'විකෘති B-disrupt.01', 'කළ I-disrupt.01', 'හැකි O', 'බව O', 'අපට O', 'කියනු O', 'ලැබේ O', '. O'], ['කෘමිනාශක O', 'DNA O', 'විකෘති O', 'කළ O', 'හැකි O', 'බව B-be.03', 'අපට O', 'කියනු O', 'ලැබේ O', '. O'], ['කෘමිනාශක B-ARG1', 'DNA I-ARG1', 'විකෘති I-ARG1', 'කළ I-ARG1', 'හැකි O', 'බව O', 'අපට B-ARG2', 'කියනු B-tell.01', 'ලැබේ I-tell.01', '. O']]
# 91.66666666666664
# [['ප්\u200dරධාන O', 'වෙනස්කම් O', 'තුනක් O', 'සිදුවී O', 'ඇත B-have.01', '. O']]
# [['ප්\u200dරධාන O', 'වෙනස්කම් O', 'තුනක් O', 'සිදුවී O', 'ඇත B-have.01', '. O']]
# 100.0
# [['එය B-ARG1', 'ඉවසිය B-tolerate.01', 'යුතු B-ARGM-MOD', 'යැයි O', 'මම O', 'විශ්වාස O', 'නොකරමි O', '. O']]
# [['එය B-ARG1', 'ඉවසිය B-tolerate.01', 'යුතු B-ARGM-MOD', 'යැයි O', 'මම O', 'විශ්වාස O', 'නොකරමි O', '. O'], ['එය O', 'ඉවසිය O', 'යුතු O', 'යැයි B-be.03', 'මම O', 'විශ්වාස O', 'නොකරමි O', '. O']]
# 99.99999999999999
# [['මෙම B-ARG0', 'රටවල් I-ARG0', 'දෙක I-ARG0', 'ස්ථාවරත්වය B-ARG1', 'භුක්ති B-enjoy.01', 'වින්දා I-enjoy.01', '. O']]
# [['මෙම B-ARG0', 'රටවල් I-ARG0', 'දෙක I-ARG0', 'ස්ථාවරත්වය B-ARG1', 'භුක්ති B-enjoy.01', 'වින්දා O', '. O']]
# 75.0
# [['මම B-ARG0', 'නැවත B-ARGM-TMP', 'උත්සාහ B-try.01', 'කරමි I-try.01', '. O']]
# [['මම B-ARG0', 'නැවත B-ARGM-TMP', 'උත්සාහ B-try.01', 'කරමි I-try.01', '. O']]
# 100.00000000000001
# [['අපි B-ARG1', 'ක්\u200dරියාශීලී O', 'විය B-be.01', 'යුතුයි B-ARGM-MOD', '. O']]
# [['අපි B-ARG1', 'ක්\u200dරියාශීලී O', 'විය B-be.01', 'යුතුයි B-ARGM-MOD', '. O']]
# 100.0
# [['මෙම B-ARG1', 'මාතෘකාව I-ARG1', 'නිසැකවම B-ARG2', 'වැදගත් I-ARG2', 'ය B-be.01', '. O']]
# [['මෙම B-ARG1', 'මාතෘකාව I-ARG1', 'නිසැකවම O', 'වැදගත් B-ARG2', 'ය B-be.01', '. O']]
# 80.0
# [['දෙවන B-ARG1', 'බරපතල I-ARG1', 'අතපසු  I-ARG1', 'කිරීම  I-ARG1', 'යුරෝ B-ARG2', 'ය B-be.01', '. O']]
# [['දෙවන B-ARG1', 'බරපතල I-ARG1', 'අතපසු O', 'කිරීම O', 'යුරෝ B-ARG2', 'ය B-be.01', '. O']]
# 83.33333333333333
# [['ඇත්තටම B-ARGM-ADV', 'සිදුවන්නේ B-happen.01', 'කුමක්ද B-ARG1', '? O', '. O']]
# [['ඇත්තටම B-ARGM-ADV', 'සිදුවන්නේ B-happen.01', 'කුමක්ද B-ARG1', '? O', '. O']]
# 100.0
# [['මෙම B-ARG1', 'භූමියේ I-ARG1', 'සාරවත් I-ARG1', 'බව  I-ARG1', 'බෙහෙවින් B-ARGM-MNR', 'අඩු B-dwindle.01', 'වෙමින් I-dwindle.01', 'පවතී I-dwindle.01', '. O']]
# [['මෙම O', 'භූමියේ O', 'සාරවත් O', 'බව B-be.03', 'බෙහෙවින් O', 'අඩු O', 'වෙමින් O', 'පවතී O', '. O'], ['මෙම B-ARG1', 'භූමියේ I-ARG1', 'සාරවත් I-ARG1', 'බව O', 'බෙහෙවින් B-ARG2', 'අඩු B-dwindle.01', 'වෙමින් I-dwindle.01', 'පවතී I-dwindle.01', '. O']]
# 83.33333333333333
# [['මෙය B-ARG0', 'ප්\u200dරජාතන්ත්\u200dරවාදයේ B-ARG1', 'සහතිකයක් I-ARG1', 'නියෝජනය B-represent.01', 'කරයි I-represent.01', '. O']]
# [['මෙය B-ARG0', 'ප්\u200dරජාතන්ත්\u200dරවාදයේ B-ARG1', 'සහතිකයක් I-ARG1', 'නියෝජනය B-represent.01', 'කරයි I-represent.01', '. O']]
# 100.0
# [['මොවුන් B-ARG2', 'සාමාන්\u200dය I-ARG2', 'රැඳවියන් I-ARG2', 'නො B-ARGM-NEG', 'වේ B-be.01', '. O']]
# [['මොවුන් B-ARG2', 'සාමාන්\u200dය I-ARG2', 'රැඳවියන් I-ARG2', 'නො I-ARG2', 'වේ B-be.01', '. O']]
# 90.0
# [['අපි B-ARG0', 'සෑම B-ARGM-TMP', 'දිනකම I-ARGM-TMP', 'විශාල B-ARG1', 'ජල I-ARG1', 'ප්\u200dරමාණයක් I-ARG1', 'භාවිතා B-use.01', 'කරමු I-use.01', '. O']]
# [['අපි B-ARG0', 'සෑම B-ARGM-TMP', 'දිනකම I-ARGM-TMP', 'විශාල B-ARG1', 'ජල I-ARG1', 'ප්\u200dරමාණයක් I-ARG1', 'භාවිතා B-use.01', 'කරමු I-use.01', '. O']]
# 100.0
# [['ඒ B-ARGM-DIS', 'නිසා I-ARGM-DIS', 'මම B-ARG0', 'මගේ B-ARG2', 'විශ්\u200dරාමිකයන්ගෙන් I-ARG2', 'ඇසුවා B-ask.01', '. O']]
# [['ඒ B-ARGM-DIS', 'නිසා I-ARGM-DIS', 'මම B-ARG0', 'මගේ B-ARG2', 'විශ්\u200dරාමිකයන්ගෙන් I-ARG2', 'ඇසුවා B-ask.01', '. O']]
# 100.0
# [['ඒ O', 'නිසා O', 'මට B-ARG0', 'විරුද්ධව I-ARG1', 'ඡන්දය B-vote.01', 'දීමට I-vote.01', 'සිදුවිය O', '. O']]
# [['ඒ B-ARG1', 'නිසා O', 'මට B-ARG0', 'විරුද්ධව I-ARG1', 'ඡන්දය B-vote.01', 'දීමට O', 'සිදුවිය O', '. O']]
# 66.66666666666667
# [['අපට B-ARG0', 'දැන් B-ARGM-TMP', 'ගෝලීය B-ARG1', 'තරඟයක් I-ARG1', 'තිබේ B-have.03', '. O']]
# [['අපට B-ARG0', 'දැන් B-ARGM-TMP', 'ගෝලීය B-ARG1', 'තරඟයක් I-ARG1', 'තිබේ B-have.03', '. O']]
# 100.0
# [['ස්වෝබොඩා B-ARG0', 'මහතා I-ARG0', 'පෙර O', 'විවාදයේදී O', 'පැහැදිලිව B-ARGM-MNR', 'කථා B-speak.01', 'කළේය I-speak.01', '. O']]
# [['ස්වෝබොඩා B-ARG0', 'මහතා I-ARG0', 'පෙර B-ARGM-LOC', 'විවාදයේදී O', 'පැහැදිලිව B-ARGM-MNR', 'කථා B-speak.01', 'කළේය I-speak.01', '. O']]
# 91.66666666666667
# [['ඒ B-ARGM-DIS', 'වෙනුවට I-ARGM-DIS', ', O', 'අපි B-ARG0', 'කරන්නේ B-do.02', 'හරියටම B-ARG1', 'ප්\u200dරතිවිරුද්ධ I-ARG1', 'දෙයයි I-ARG1', '. O']]
# [['ඒ O', 'වෙනුවට O', ', O', 'අපි O', 'කරන්නේ B-be.03', 'හරියටම O', 'ප්\u200dරතිවිරුද්ධ O', 'දෙයයි O', '. O']]
# 0
# [['මෙය B-ARG1', 'නරුම B-ARG2', 'ප්\u200dරවේශයක් I-ARG2', 'ලෙස I-ARG2', 'මම B-ARG0', 'සලකමි B-regard.01', '. O']]
# [['මෙය B-ARG1', 'නරුම B-ARG2', 'ප්\u200dරවේශයක් I-ARG2', 'ලෙස I-ARG2', 'මම B-ARG0', 'සලකමි B-regard.01', '. O']]
# 100.0
# [['ගෑස් B-ARG1', 'අර්බුදය I-ARG1', 'විසඳී B-resolve.01', 'නැත B-ARGM-NEG', '. O']]
# [['ගෑස් O', 'අර්බුදය O', 'විසඳී O', 'නැත O', '. O  B-be.03', '. O']]
# 0
# [['අපි B-ARG0', 'තවත් B-ARG1', 'බොහෝ O', 'දේ O', 'කළ B-do.01', 'යුතුද O', '? O', '. O'], ['අපි B-ARG0', 'තවත් B-ARG1', 'බොහෝ O', 'දේ O', 'කළ I-ARG1', 'යුතුද B-need.01', '? O', '. O']]
# [['අපි O', 'තවත් O', 'බොහෝ O', 'දේ O', 'කළ B-do.01', 'යුතුද O', '? O', '. O']]
# 42.85714285714285
# [['අපහාස B-ARG1', 'කිරීමේ I-ARG1', 'හැකියාව I-ARG1', 'ද B-ARGM-ADV', 'තිබේ B-be.02', '. O']]
# [['අපහාස B-ARG1', 'කිරීමේ I-ARG1', 'හැකියාව I-ARG1', 'ද B-ARGM-ADV', 'තිබේ B-be.02', '. O']]
# 100.0
# [['මේක B-ARG1', 'අවුලක් B-ARG2', ', O', 'කොමසාරිස් B-ARGM-DIS', '! O', '. O']]
# [['මේක B-ARG1', 'අවුලක් B-ARG2', ', O', 'කොමසාරිස් B-ARGM-DIS', '! O', '. O']]
# 100.00000000000001
# [['අපි B-ARG0', 'කතා B-speak.01', 'කරන්නේ I-speak.01', 'එක B-ARGM-MNR', 'කටහඬකින් I-ARGM-MNR', 'නො B-ARGM-NEG', 'වේ O', '. O']]
# [['අපි B-ARG0', 'කතා B-speak.01', 'කරන්නේ I-speak.01', 'එක B-ARGM-MNR', 'කටහඬකින් I-ARGM-MNR', 'නො B-ARGM-NEG', 'වේ O', '. O'], ['අපි O', 'කතා O', 'කරන්නේ O', 'එක O', 'කටහඬකින් O', 'නො O', 'වේ B-be.03', '. O']]
# 99.99999999999999
# [['පොඩි B-ARG1', 'ගෞරවයක් I-ARG1', 'පෙන්වන්න B-show.01', '. O']]
# [['පොඩි B-ARG1', 'ගෞරවයක් I-ARG1', 'පෙන්වන්න B-show.01', '. O']]
# 100.00000000000001
# [['කොමසාරිස් B-ARG1', 'හරි B-ARG2', '. O']]
# [['කොමසාරිස් B-ARG1', 'හරි B-ARG2', '. O']]
# 100.0
# [['මෙයින් B-ARG0', 'අදහස් B-mean.01', 'කරන්නේ I-mean.01', 'වැඩිදුර B-ARG1', 'සාකච්ඡා I-ARG1', 'ඇති  I-ARG1', 'බවයි I-ARG1', '. O'], ['මෙයින් O', 'අදහස් O', 'කරන්නේ O', 'වැඩිදුර B-ARG1', 'සාකච්ඡා I-ARG1', 'ඇති O', 'බවයි B-be.02', '. O']]
# [['මෙයින් B-ARG0', 'අදහස් B-mean.01', 'කරන්නේ I-mean.01', 'වැඩිදුර B-ARG1', 'සාකච්ඡා I-ARG1', 'ඇති O', 'බවයි I-ARG1', '. O'], ['මෙයින් O', 'අදහස් O', 'කරන්නේ O', 'වැඩිදුර B-ARG1', 'සාකච්ඡා I-ARG1', 'ඇති O', 'බවයි B-be.02', '. O']]
# 95.83333333333331
# [['මම B-ARG0', 'එයට B-ARG1', 'විරුද්ධව I-ARG1', 'ඡන්දය B-vote.01', 'දුන්නා I-vote.01', '. O']]
# [['මම B-ARG0', 'එයට B-ARG1', 'විරුද්ධව I-ARG1', 'ඡන්දය O', 'දුන්නා B-vote.01', '. O']]
# 50.0
# [['එය B-ARG1', 'සිදුවීමට B-happen.01', 'හේතුව B-ARGM-CAU', 'මට O', 'අහන්න O', 'පුළුවන්ද O', '? O', '. O'], ['එය B-ARG1', 'සිදුවීමට I-ARG1', 'හේතුව I-ARG1', 'මට B-ARG0', 'අහන්න B-ask.01', 'පුළුවන්ද B-ARGM-MOD', '? O', '. O']]
# [['එය B-ARG1', 'සිදුවීමට B-happen.01', 'හේතුව B-ARGM-CAU', 'මට O', 'අහන්න O', 'පුළුවන්ද O', '? O', '. O'], ['එය B-ARG1', 'සිදුවීමට I-ARG1', 'හේතුව I-ARG1', 'මට B-ARG0', 'අහන්න B-ask.01', 'පුළුවන්ද O', '? O', '. O']]
# 96.42857142857142
# [['මෙය B-ARG1', 'විපර්යාස B-ARG1', 'වූ I-ARG1', 'ඉඩමකි B-be.01', '. O']]
# [['මෙය B-ARG1', 'විපර්යාස O', 'වූ O', 'ඉඩමකි B-be.01', '. O']]
# 75.0
# [['මෙය B-ARG1', 'නීත්\u200dයානුකූල B-ARG2', 'බැඳීමක් I-ARG2', 'විය B-be.01', 'යුතුය B-ARGM-MOD', '. O']]
# [['මෙය B-ARG1', 'නීත්\u200dයානුකූල B-ARG2', 'බැඳීමක් I-ARG2', 'විය B-be.01', 'යුතුය B-ARGM-MOD', '. O']]
# 100.0
# [['ඡන්ද B-ARG1', 'විමසීම I-ARG1', 'බ්\u200dරහස්පතින්දා B-ARGM-TMP', 'සිදු B-take.14', 'වෙයි I-take.14', '. O']]
# [['ඡන්ද B-ARG1', 'විමසීම O', 'බ්\u200dරහස්පතින්දා B-ARGM-TMP', 'සිදු B-take.14', 'වෙයි I-take.14', '. O']]
# 87.5
# [['එය B-ARG1', 'උතුරු B-ARG2', 'අයර්ලන්තයේ I-ARG2', 'නරකම I-ARG2', 'බියකරු I-ARG2', 'සිහිනයයි I-ARG2', '. O']]
# [['එය B-ARG1', 'උතුරු B-ARG2', 'අයර්ලන්තයේ I-ARG2', 'නරකම I-ARG2', 'බියකරු I-ARG2', 'සිහිනයයි O', '. O  B-be.01', '. O']]
# 85.71428571428572
# [['ඇත්ත B-ARG1', 'වශයෙන්ම I-ARG1', 'කිසිවක් I-ARG1', 'කරනු I-ARG1', 'ඇත්ද I-ARG1', 'යන්න B-be.01', 'සැක B-ARG2', 'සහිතය I-ARG2', '. O'], ['ඇත්ත B-ARGM-ADV', 'වශයෙන්ම I-ARGM-ADV', 'කිසිවක් B-ARG1', 'කරනු B-do.02', 'ඇත්ද O', 'යන්න O', 'සැක O', 'සහිතය O', '. O']]
# [['ඇත්ත O', 'වශයෙන්ම O', 'කිසිවක් O', 'කරනු O', 'ඇත්ද B-be.03', 'යන්න O', 'සැක O', 'සහිතය O', '. O'], ['ඇත්ත B-ARG1', 'වශයෙන්ම O', 'කිසිවක් I-ARG1', 'කරනු I-ARG1', 'ඇත්ද I-ARG1', 'යන්න B-be.01', 'සැක B-ARG2', 'සහිතය I-ARG1', '. O'], ['ඇත්ත B-ARGM-ADV', 'වශයෙන්ම O', 'කිසිවක් B-ARG1', 'කරනු B-ARGM-MOD', 'ඇත්ද O', 'යන්න O', 'සැක O', 'සහිතය B-do.02', '. O']]
# 21.875
# [['පවසා B-say.01', 'ඇති O', 'දේ B-ARG1', 'අසත්\u200dයය O', '. O'], ['පවසා B-ARG1', 'ඇති I-ARG1', 'දේ I-ARG1', 'අසත්\u200dයය B-ARG2', '. O']]
# [['පවසා B-say.01', 'ඇති O', 'දේ B-ARG1', 'අසත්\u200dයය O', '. O'], ['පවසා O', 'ඇති B-have.01', 'දේ O', 'අසත්\u200dයය O', '. O']]
# 100.0
# [['මෙම B-ARG2', 'වාර්තාවේ I-ARG2', 'මෙම I-ARG2', 'අංගයට I-ARG2', 'මම B-ARG0', 'එකඟ B-disagree.01', 'නොවෙමි I-disagree.01', '. O']]
# [['මෙම B-ARG2', 'වාර්තාවේ I-ARG2', 'මෙම I-ARG2', 'අංගයට I-ARG2', 'මම B-ARG0', 'එකඟ B-disagree.01', 'නොවෙමි I-disagree.01', '. O']]
# 100.0
# [['කෙසේ B-ARGM-DIS', 'වෙතත් I-ARGM-DIS', ', O', 'මම B-ARG1', 'තරමක් B-ARG2', 'ශුභවාදී I-ARG2', 'ය B-be.01', '. O']]
# [['කෙසේ B-ARGM-DIS', 'වෙතත් O', ', O', 'මම B-ARG1', 'තරමක් B-ARG2', 'ශුභවාදී I-ARG2', 'ය B-be.01', '. O']]
# 92.85714285714286
# [['මේ B-ARG0', 'සඳහා O', 'අධිෂ්ඨානය B-ARG1', 'සහ I-ARG1', 'පරිකල්පනය I-ARG1', 'අවශ්\u200dය B-require.01', 'වේ I-require.01', '. O']]
# [['මේ B-ARG0', 'සඳහා O', 'අධිෂ්ඨානය B-ARG1', 'සහ I-ARG1', 'පරිකල්පනය I-ARG1', 'අවශ්\u200dය B-require.01', 'වේ I-require.01', '. O']]
# 100.0
# [['ඊට B-ARG1', 'වඩා I-ARG1', 'ප්\u200dරායෝගික I-ARG1', 'හේතු I-ARG1', 'ද B-ARGM-ADV', 'තිබේ B-be.02', '. O']]
# [['ඊට B-ARG1', 'වඩා I-ARG1', 'ප්\u200dරායෝගික I-ARG1', 'හේතු I-ARG1', 'ද B-ARGM-ADV', 'තිබේ B-be.02', '. O']]
# 100.0
# [['මම B-ARG0', 'ඔබ B-ARG1', 'සැමට I-ARG1', 'ස්තූතියි B-thank.01', '. O']]
# [['මම B-ARG0', 'ඔබ B-ARG1', 'සැමට I-ARG1', 'ස්තූතියි B-thank.01', '. O']]
# 100.0
# [['එය B-ARG1', 'කොන්දේසි B-ARG2', 'විරහිත I-ARG2', 'ය B-be.01', '. O']]
# [['එය B-ARG1', 'කොන්දේසි B-ARG2', 'විරහිත O', 'ය B-be.01', '. O']]
# 87.5
# [['මෙම B-ARG0', 'සම්මුතිය I-ARG0', 'ඔවුන්ගේ B-ARG2', 'බිය I-ARG2', 'සැලකිල්ලට B-take.01', 'ගනියි I-take.01', '. O']]
# [['මෙම B-ARG0', 'සම්මුතිය I-ARG0', 'ඔවුන්ගේ B-ARG2', 'බිය I-ARG2', 'සැලකිල්ලට B-take.01', 'ගනියි I-take.01', '. O']]
# 100.0
# [['මෙම B-ARG1', 'ඉලක්කය I-ARG1', 'තරමක I-ARG1', 'විකාරයක් I-ARG1', 'ලෙස B-seem.01', 'පෙනෙයි I-seem.01', '. O']]
# [['මෙම B-ARG1', 'ඉලක්කය I-ARG1', 'තරමක I-ARG1', 'විකාරයක් I-ARG1', 'ලෙස O', 'පෙනෙයි B-seem.01', '. O']]
# 50.0
# [['බලපෑමට B-affect.01', 'ලක්වූ O', 'තනි B-ARG1', 'පුරවැසියන්ට I-ARG1', 'වන්දි O', 'ගෙවන්නේ O', 'කවුද O', '? O', '. O'], ['බලපෑමට B-ARG1', 'ලක්වූ I-ARG1', 'තනි I-ARG1', 'පුරවැසියන්ට I-ARG1', 'වන්දි B-compensate.01', 'ගෙවන්නේ I-compensate.01', 'කවුද B-ARG0', '? O', '. O']]
# ...
# 91.66666666666666
# [['අපි B-ARG1', 'ඉන්නේ B-be.01', '2009 B-ARG2', 'වර්ෂයේ I-ARG2', '. O']]
# [['අපි B-ARG1', 'ඉන්නේ B-be.01', '2009 B-ARG2', 'වර්ෂයේ I-ARG2', '. O']]
# 100.0
# [['අපට B-ARG0', 'ද්වි B-ARG1', 'මාර්ග I-ARG1', 'සංවාදයක් I-ARG1', 'තිබුණේ B-have.03', 'නම් O', 'පමණි O', '. O']]
# [['අපට B-ARG0', 'ද්වි B-ARG1', 'මාර්ග I-ARG1', 'සංවාදයක් I-ARG1', 'තිබුණේ B-have.03', 'නම් O', 'පමණි O', '. O']]
# 99.99999999999999
# [['මේ B-ARG1', 'සියල්ල I-ARG1', 'අපි B-ARG0', 'දනිමු B-know.01', '. O']]
# [['මේ B-ARG1', 'සියල්ල I-ARG1', 'අපි B-ARG0', 'දනිමු B-know.01', '. O']]
# 100.0
# [['එම B-ARG1', 'වගකීම් I-ARG1', 'හරියටම B-ARGM-ADV', 'කුමක්ද B-ARG2', '? O', '. O']]
# [['එම B-ARG1', 'වගකීම් I-ARG1', 'හරියටම O', 'කුමක්ද B-ARG2', '? O', '. O']]
# 83.33333333333334
# [['මෙම B-ARG0', 'පැකේජයේ I-ARG0', 'ඉතා B-ARG1', 'යාවත්කාලීන I-ARG1', 'හා I-ARG1', 'ප්\u200dරගතිශීලී I-ARG1', 'යෝජනා I-ARG1', 'අඩංගු B-contain.01', 'වේ I-contain.01', '. O']]
# [['මෙම B-ARG0', 'පැකේජයේ I-ARG0', 'ඉතා B-ARG1', 'යාවත්කාලීන I-ARG1', 'හා I-ARG1', 'ප්\u200dරගතිශීලී I-ARG1', 'යෝජනා I-ARG1', 'අඩංගු B-contain.01', 'වේ I-contain.01', '. O']]
# 100.0
# [['එබැවින් B-ARGM-ADV', 'මෙම B-ARG1', 'යෝජනාව I-ARG1', 'ප්\u200dරතික්ෂේප B-reject.01', 'කළ I-reject.01', 'යුතුය B-ARGM-MOD', '. O']]
# [['එබැවින් B-ARGM-ADV', 'මෙම B-ARG1', 'යෝජනාව I-ARG1', 'ප්\u200dරතික්ෂේප B-reject.01', 'කළ I-reject.01', 'යුතුය B-ARGM-MOD', '. O']]
# 100.0
# [['අපි B-ARG0', 'මෙම B-ARG1', 'සාර්ථකත්ව I-ARG1', 'පදනම I-ARG1', 'ආරක්ෂා B-safeguard.01', 'කළ I-safeguard.01', 'යුතු B-ARGM-MOD', 'වෙමු O', '. O']]
# [['අපි B-ARG0', 'මෙම B-ARG1', 'සාර්ථකත්ව I-ARG1', 'පදනම I-ARG1', 'ආරක්ෂා B-safeguard.01', 'කළ I-safeguard.01', 'යුතු B-ARGM-MOD', 'වෙමු O', '. O']]
# 99.99999999999999
# [['ඔබගේ B-ARG1', 'සහයෝගය I-ARG1', 'බෙහෙවින් B-ARG2', 'අගය I-ARG2', 'කර I-ARG2', 'ඇත O', '. O'], ['ඔබගේ B-ARG1', 'සහයෝගය I-ARG1', 'බෙහෙවින් B-ARGM-EXT', 'අගය B-appreciate.02', 'කර I-appreciate.02', 'ඇත I-appreciate.02', '. O']]
# [['ඔබගේ O', 'සහයෝගය O', 'බෙහෙවින් O', 'අගය O', 'කර O', 'ඇත B-have.01', '. O']]
# 0
# [['යුරෝපය B-ARG0', 'වෙනත් B-ARG1', 'මාර්ගයක් I-ARG1', 'ගත B-take.LV', 'යුතුය B-ARGM-MOD', '. O']]
# [['යුරෝපය B-ARG0', 'වෙනත් B-ARG1', 'මාර්ගයක් I-ARG1', 'ගත B-take.LV', 'යුතුය B-ARGM-MOD', '. O']]
# 100.0
# [['මෙය B-ARG1', 'නිවැරදි I-ARG1', 'දැයි I-ARG1', 'ඔබට B-ARG0', 'තහවුරු B-confirm.01', 'කළ I-confirm.01', 'හැකිද B-ARGM-MOD', '? O', '. O']]
# [['මෙය B-ARG1', 'නිවැරදි I-ARG1', 'දැයි O', 'ඔබට B-ARG0', 'තහවුරු B-confirm.01', 'කළ I-confirm.01', 'හැකිද B-ARGM-MOD', '? O', '. O']]
# 92.85714285714285
# [['අපගේ B-ARG1', 'ප්\u200dරවේශය I-ARG1', 'පදනම් B-base.02', 'වී I-base.02', 'ඇත්තේ I-base.02', 'මෙම B-ARG2', 'ස්ථාපිත I-ARG2', 'අයිතිය I-ARG2', 'මත I-ARG2', 'ය O', '. O'], ['අපගේ O', 'ප්\u200dරවේශය O', 'පදනම් O', 'වී O', 'ඇත්තේ O', 'මෙම O', 'ස්ථාපිත B-establish.01', 'අයිතිය B-ARG1', 'මත O', 'ය O', '. O'], ['අපගේ B-ARG1', 'ප්\u200dරවේශය I-ARG1', 'පදනම් B-ARG2', 'වී I-ARG2', 'ඇත්තේ O', 'මෙම I-ARG2', 'ස්ථාපිත I-ARG2', 'අයිතිය I-ARG2', 'මත I-ARG2', 'ය B-be.03', '. O']]
# [['අපගේ B-ARG1', 'ප්\u200dරවේශය I-ARG1', 'පදනම් B-base.02', 'වී I-base.02', 'ඇත්තේ O', 'මෙම B-ARG2', 'ස්ථාපිත I-ARG2', 'අයිතිය I-ARG2', 'මත I-ARG2', 'ය O', '. O'], ['අපගේ O', 'ප්\u200dරවේශය O', 'පදනම් O', 'වී O', 'ඇත්තේ O', 'මෙම O', 'ස්ථාපිත B-establish.01', 'අයිතිය B-ARG1', 'මත O', 'ය O', '. O'], ['අපගේ O', 'ප්\u200dරවේශය O', 'පදනම් B-ARG2', 'වී I-ARG2', 'ඇත්තේ O', 'මෙම I-ARG2', 'ස්ථාපිත I-ARG2', 'අයිතිය I-ARG2', 'මත I-ARG2', 'ය B-be.03', '. O']]
# 91.11111111111113
# [['එයින් B-ARG0', 'පෙන්නුම් B-show.01', 'කරන්නේ I-show.01', 'අප B-ARG1', 'කොතරම් I-ARG1', 'පිටුපසින් I-ARG1', 'සිටිනවාද I-ARG1', 'යන්නයි O', '. O'], ['එයින් O', 'පෙන්නුම් O', 'කරන්නේ O', 'අප B-ARG1', 'කොතරම් B-ARG2', 'පිටුපසින් I-ARG2', 'සිටිනවාද B-be.01', 'යන්නයි O', '. O']]
# [['එයින් B-ARG0', 'පෙන්නුම් B-show.01', 'කරන්නේ I-show.01', 'අප B-ARG1', 'කොතරම් I-ARG1', 'පිටුපසින් I-ARG1', 'සිටිනවාද I-ARG1', 'යන්නයි O', '. O'], ['එයින් O', 'පෙන්නුම් O', 'කරන්නේ O', 'අප B-ARG1', 'කොතරම් B-ARG2', 'පිටුපසින් I-ARG2', 'සිටිනවාද B-be.01', 'යන්නයි O', '. O']]
# 99.99999999999999
# [['පිළිතුර B-ARG1', ', O', 'ඇත්ත B-ARGM-ADV', 'වශයෙන්ම I-ARGM-ADV', 'නැත B-ARG2', '. O']]
# [['පිළිතුර B-ARG1', ', O', 'ඇත්ත O', 'වශයෙන්ම B-ARGM-ADV', 'නැත B-ARG2', '. O  B-be.01', '. O']]
# 66.66666666666667
# [['එහි B-ARGM-LOC', 'විශාල B-ARG1', 'ගනුදෙනුවක් I-ARG1', 'කළ B-do.02', 'හැකිය B-ARGM-MOD', '. O']]
# [['එහි B-ARGM-LOC', 'විශාල B-ARG1', 'ගනුදෙනුවක් I-ARG1', 'කළ B-do.02', 'හැකිය B-ARGM-MOD', '. O']]
# 100.0
# [['එබැවින් B-ARGM-DIS', 'අපට B-ARG0', 'වඩා B-ARG1', 'හොඳ I-ARG1', 'නියාමනයක් I-ARG1', 'අවශ්\u200dය B-need.01', 'වේ I-need.01', '. O']]
# [['එබැවින් B-ARGM-DIS', 'අපට B-ARG0', 'වඩා O', 'හොඳ B-ARG1', 'නියාමනයක් I-ARG1', 'අවශ්\u200dය B-need.01', 'වේ I-need.01', '. O']]
# 83.33333333333333
# [['අපට B-ARG0', 'ආරක්ෂක B-ARG1', 'කර්මාන්ත I-ARG1', 'අවශ්\u200dය B-need.01', 'වන්නේ I-need.01', 'එබැවිනි B-ARGM-CAU', '. O']]
# [['අපට B-ARG0', 'ආරක්ෂක B-ARG1', 'කර්මාන්ත I-ARG1', 'අවශ්\u200dය B-need.01', 'වන්නේ I-need.01', 'එබැවිනි B-ARGM-CAU', '. O']]
# 100.0
# [['අපට B-ARG0', 'කළ B-do.02', 'හැක්කේ B-ARGM-MOD', 'එයයි B-ARG1', '. O'], ['අපට B-ARG2', 'කළ I-ARG2', 'හැක්කේ I-ARG2', 'එයයි B-ARG1', '. O']]
# [['අපට B-ARG0', 'කළ B-do.02', 'හැක්කේ B-ARGM-MOD', 'එයයි O', '. O']]
# 87.5
# [['එබැවින් B-ARGM-DIS', 'මම B-ARG0', 'වාර්තාවට B-ARG1', 'විරුද්ධව I-ARG1', 'ඡන්දය B-vote.01', 'ප්\u200dරකාශ I-vote.01', 'කළෙමි I-vote.01', '. O']]
# [['එබැවින් B-ARGM-DIS', 'මම B-ARG0', 'වාර්තාවට B-ARG1', 'විරුද්ධව I-ARG1', 'ඡන්දය B-vote.01', 'ප්\u200dරකාශ O', 'කළෙමි O', '. O']]
# 66.66666666666666
# [['අපගේ B-ARG1', 'අනිවාර්ය I-ARG1', 'ඉන්ධන I-ARG1', 'සංචිත I-ARG1', 'වැඩි B-increase.01', 'කර I-increase.01', 'ගන්නේද O', '? O', '. O']]
# [['අපගේ B-ARG1', 'අනිවාර්ය I-ARG1', 'ඉන්ධන I-ARG1', 'සංචිත I-ARG1', 'වැඩි B-increase.01', 'කර I-increase.01', 'ගන්නේද O', '? O', '. O']]
# 99.99999999999999
# [['කවුන්සිලය B-ARG1', 'අද B-ARGM-TMP', 'සවස I-ARGM-TMP', 'මෙහි B-ARG2', 'නැත B-ARGM-NEG', '. O']]
# [['කවුන්සිලය B-ARG1', 'අද B-ARGM-TMP', 'සවස I-ARGM-TMP', 'මෙහි B-ARG2', 'නැත B-ARGM-NEG', '. O  B-be.01', '. O']]
# 100.00000000000001
# [['මම B-ARG0', 'එය B-ARG1', 'බොහෝ B-ARGM-LOC', 'තැන්වල I-ARGM-LOC', 'දැක B-see.01', 'ඇත්තෙමි I-see.01', '. O']]
# [['මම B-ARG0', 'එය B-ARG1', 'බොහෝ B-ARGM-LOC', 'තැන්වල I-ARGM-LOC', 'දැක B-see.01', 'ඇත්තෙමි I-see.01', '. O']]
# 100.0
# [['අපට B-ARG0', 'ශක්තිමත් B-ARG1', 'ආයතන I-ARG1', 'අවශ්\u200dය B-need.01', 'වන්නේ I-need.01', 'එබැවිනි B-ARGM-CAU', '. O']]
# [['අපට B-ARG0', 'ශක්තිමත් B-ARG1', 'ආයතන I-ARG1', 'අවශ්\u200dය B-need.01', 'වන්නේ I-need.01', 'එබැවිනි B-ARGM-CAU', '. O']]
# 100.0
# [['මෙම B-ARG1', 'ක්\u200dරමය I-ARG1', 'වැරදිය B-ARG2', '. O']]
# [['මෙම B-ARG1', 'ක්\u200dරමය I-ARG1', 'වැරදිය B-ARG2', '. O']]
# 100.0
# [['මෙම O', 'නම්යතාවය O', 'පහත B-follow.04', 'සඳහන් O', 'කරුණු B-ARG1', 'ඇතුළත් O', 'විය O', 'යුතුය O', '. O'], ['මෙම B-ARG0', 'නම්යතාවය I-ARG0', 'පහත B-ARG1', 'සඳහන් I-ARG1', 'කරුණු I-ARG1', 'ඇතුළත් B-encompass.01', 'විය I-encompass.01', 'යුතුය B-ARGM-MOD', '. O']]
# [['මෙම O', 'නම්යතාවය O', 'පහත B-follow.04', 'සඳහන් O', 'කරුණු B-ARG1', 'ඇතුළත් O', 'විය O', 'යුතුය O', '. O']]
# 50.0
# [['මෙය B-ARG1', 'අතිශයින්ම B-ARG2', 'වැදගත් I-ARG2', 'ය B-be.01', '. O']]
# [['මෙය B-ARG1', 'අතිශයින්ම B-ARG2', 'වැදගත් I-ARG2', 'ය B-be.01', '. O']]
# 100.0
# [['ඒ B-ARGM-CAU', 'සඳහා I-ARGM-CAU', 'අපි B-ARG0', 'ඔහුට B-ARG2', 'විශේෂ B-ARG1', 'ගෞරවයක් I-ARG1', 'දිය B-give.01', 'යුතුයි B-ARGM-MOD', '. O']]
# [['ඒ B-ARGM-CAU', 'සඳහා I-ARGM-CAU', 'අපි B-ARG0', 'ඔහුට B-ARG2', 'විශේෂ B-ARG1', 'ගෞරවයක් I-ARG1', 'දිය B-give.01', 'යුතුයි B-ARGM-MOD', '. O']]
# 100.0
# [['හොඳ B-ARG1', 'අසල්වැසි I-ARG1', 'සබඳතා I-ARG1', 'වැඩිදියුණු B-improve.01', 'කිරීමේ I-improve.01', 'උත්සාහයන් O', 'අඛණ්ඩව O', 'පැවතිය O', 'යුතුය O', '. O'], ['හොඳ B-ARG1', 'අසල්වැසි I-ARG1', 'සබඳතා I-ARG1', 'වැඩිදියුණු I-ARG1', 'කිරීමේ I-ARG1', 'උත්සාහයන් I-ARG1', 'අඛණ්ඩව B-continue.01', 'පැවතිය I-continue.01', 'යුතුය B-ARGM-MOD', '. O']]
# [['හොඳ B-ARG1', 'අසල්වැසි I-ARG1', 'සබඳතා I-ARG1', 'වැඩිදියුණු B-improve.01', 'කිරීමේ I-improve.01', 'උත්සාහයන් O', 'අඛණ්ඩව O', 'පැවතිය O', 'යුතුය O', '. O'], ['හොඳ B-ARG1', 'අසල්වැසි I-ARG1', 'සබඳතා I-ARG1', 'වැඩිදියුණු I-ARG1', 'කිරීමේ I-ARG1', 'උත්සාහයන් I-ARG1', 'අඛණ්ඩව B-continue.01', 'පැවතිය O', 'යුතුය B-ARGM-MOD', '. O']]
# 87.5
# [['සමහර B-ARGM-ADV', 'විට I-ARGM-ADV', 'ඔබට I-ARG0', 'මතකද B-remember.01', 'පාද B-ARG1', 'සහ I-ARG1', 'මුඛ I-ARG1', 'රෝග I-ARG1', 'පැතිරීම I-ARG1', '? O', '. O']]
# [['සමහර B-ARG0', 'විට I-ARG0', 'ඔබට I-ARG0', 'මතකද B-remember.01', 'පාද B-ARG1', 'සහ I-ARG1', 'මුඛ I-ARG1', 'රෝග I-ARG1', 'පැතිරීම O', '? O', '. O']]
# 85.0
# [['ස්තූතියි B-thank.01', 'සහ O', 'සුභ O', 'පැතුම් O', '. O']]
# [['ස්තූතියි B-thank.01', 'සහ O', 'සුභ O', 'පැතුම් O', '. O']]
# 100.0
# [['යුරෝපීය B-ARGM-LOC', 'කවුන්සිලය I-ARGM-LOC', 'තුළ I-ARGM-LOC', 'තවත් B-ARG1', 'බොහෝ I-ARG1', 'දේ I-ARG1', 'කළ B-do.02', 'යුතුය B-ARGM-MOD', '. O']]
# [['යුරෝපීය B-ARGM-LOC', 'කවුන්සිලය I-ARGM-LOC', 'තුළ I-ARGM-LOC', 'තවත් B-ARG1', 'බොහෝ O', 'දේ O', 'කළ B-do.02', 'යුතුය B-ARGM-MOD', '. O']]
# 87.5
# [['මේ B-ARGM-TMP', 'මොහොතේ I-ARGM-TMP', 'අපි B-ARG0', 'නො B-ARGM-NEG', 'දනිමු B-know.01', '. O']]
# [['මේ B-ARGM-TMP', 'මොහොතේ I-ARGM-TMP', 'අපි B-ARG0', 'නො B-ARGM-NEG', 'දනිමු B-know.01', '. O']]
# 100.0
# [['එය B-ARG1', 'හාස්\u200dයජනකය B-ARG2', '. O']]
# [['එය B-ARG1', 'හාස්\u200dයජනකය B-ARG2', '. O  B-be.01', '. O']]
# 100.0
# [['සෑම B-ARG1', 'සමාජ I-ARG1', 'කණ්ඩායමක්ම I-ARG1', 'වෙනස් B-ARG2', 'ය B-be.01', '. O']]
# [['සෑම B-ARG1', 'සමාජ I-ARG1', 'කණ්ඩායමක්ම I-ARG1', 'වෙනස් B-ARG2', 'ය B-be.01', '. O']]
# 100.0
# [['පළමුවැන්න B-ARG1', 'ඇත්ත B-ARGM-ADV', 'වශයෙන්ම I-ARGM-ADV', 'රැකියා B-ARG2', 'ය B-be.01', '. O']]
# [['පළමුවැන්න B-ARG1', 'ඇත්ත O', 'වශයෙන්ම B-ARGM-ADV', 'රැකියා B-ARG2', 'ය B-be.01', '. O']]
# 80.0
# [['Qimonda B-ARG1', 'ට I-ARG1', 'සහය B-support.01', 'නො B-ARGM-NEG', 'දක්වන්නේ B-ARGM-ADV', 'ඇයි B-ARGM-CAU', '? O', '. O']]
# [['Qimonda B-ARG1', 'ට O', 'සහය B-support.01', 'නො B-ARGM-NEG', 'දක්වන්නේ B-ARGM-ADV', 'ඇයි B-ARGM-CAU', '? O', '. O']]
# 92.85714285714285
# [['ඔබ B-ARG0', 'දැන් B-ARGM-TMP', 'එය B-ARG1', 'නිවැරදි B-put.03', 'කර I-put.03', 'ඇත B-have.01', '. O']]
# [['ඔබ O', 'දැන් O', 'එය O', 'නිවැරදි O', 'කර O', 'ඇත B-have.01', '. O']]
# 0
# [['මෙය B-ARG1', 'අත්\u200dයවශ්\u200dය B-ARG2', 'නො I-ARG2', 'වේ B-be.01', '. O']]
# [['මෙය B-ARG1', 'අත්\u200dයවශ්\u200dය B-ARG2', 'නො I-ARG2', 'වේ B-be.01', '. O']]
# 100.0
# [['මට B-ARG0', 'ඉක්මන් B-ARG1', 'කරුණු I-ARG1', 'දෙකක් I-ARG1', 'තිබේ B-have.03', '. O']]
# [['මට B-ARG0', 'ඉක්මන් B-ARG1', 'කරුණු I-ARG1', 'දෙකක් I-ARG1', 'තිබේ B-have.03', '. O']]
# 100.0
# [['ඉතින් B-ARGM-DIS', 'අපි B-ARG0', 'හැමෝම I-ARG0', 'ඒ B-ARG1', 'ගැන I-ARG1', 'බලාපොරොත්තු B-hope.01', 'වෙනවා I-hope.01', '. O']]
# [['ඉතින් B-ARGM-DIS', 'අපි B-ARG0', 'හැමෝම O', 'ඒ B-ARG1', 'ගැන I-ARG1', 'බලාපොරොත්තු B-hope.01', 'වෙනවා I-hope.01', '. O']]
# 91.66666666666667
# [['මෙම B-ARG1', 'මුල I-ARG1', 'පිරීම්වලට I-ARG1', 'කිසිවක් B-ARG2', 'වියදම් B-cost.01', 'කිරීමට I-cost.01', 'අවශ්\u200dය O', 'නැත O', '. O']]
# [['මෙම B-ARG1', 'මුල I-ARG1', 'පිරීම්වලට O', 'කිසිවක් B-ARG2', 'වියදම් B-cost.01', 'කිරීමට O', 'අවශ්\u200dය O', 'නැත O', '. O'], ['මෙම O', 'මුල O', 'පිරීම්වලට O', 'කිසිවක් O', 'වියදම් O', 'කිරීමට B-do.01', 'අවශ්\u200dය O', 'නැත O', '. O']]
# 67.85714285714286
# [['හොඳ B-ARG1', 'මනසක් I-ARG1', 'ඇති I-ARG1', 'ඕනෑම I-ARG1', 'කෙනෙක් I-ARG1', 'සාමකාමී B-ARG2', 'ය B-be.01', '. O']]
# [['හොඳ B-ARG1', 'මනසක් I-ARG1', 'ඇති O', 'ඕනෑම O', 'කෙනෙක් O', 'සාමකාමී O', 'ය B-be.01', '. O']]
# 71.42857142857142
# [['මෙය B-ARG1', 'විශිෂ්ට B-ARG2', 'ප්\u200dරතිඵලයක් I-ARG2', 'විය B-be.01', '. O']]
# [['මෙය B-ARG1', 'විශිෂ්ට B-ARG2', 'ප්\u200dරතිඵලයක් I-ARG2', 'විය B-be.01', '. O']]
# 100.0
# [['ප්\u200dරශ්නය B-ARG1', 'මෙය B-ARG2', 'අහම්බයක් I-ARG2', 'ද I-ARG2', 'යන්නයි I-ARG2', '. O'], ['ප්\u200dරශ්නය O', 'මෙය B-ARG1', 'අහම්බයක් I-ARG2', 'ද B-be.01', 'යන්නයි O', '. O']]
# [['ප්\u200dරශ්නය B-ARG1', 'මෙය I-ARG1', 'අහම්බයක් B-ARG2', 'ද O', 'යන්නයි O', '. O']]
# 0
# [['නිශ්ශබ්දතාවය B-ARG1', 'ළමා B-ARG2', 'රෝගයේ I-ARG2', 'හොඳම I-ARG2', 'මිතුරා I-ARG2', 'වේ B-be.01', '. O']]
# [['නිශ්ශබ්දතාවය B-ARG1', 'ළමා O', 'රෝගයේ B-ARG2', 'හොඳම I-ARG2', 'මිතුරා I-ARG2', 'වේ B-be.01', '. O']]
# 83.33333333333333
# [['මෙය B-ARG1', 'සාර්ථකව B-ARGM-MNR', 'අවසන් B-complete.01', 'කර I-complete.01', 'ඇත I-complete.01', '. O']]
# [['මෙය B-ARG1', 'සාර්ථකව B-ARGM-MNR', 'අවසන් B-complete.01', 'කර I-complete.01', 'ඇත O', '. O'], ['මෙය O', 'සාර්ථකව O', 'අවසන් O', 'කර O', 'ඇත B-have.01', '. O']]
# 83.33333333333334
# [['මැවිල්ලට B-ARG0', 'නිර්මාණකරුවෙකු B-ARG1', 'සිටින B-have.03', 'බැවිනි O', '. O']]
# [['මැවිල්ලට B-ARG0', 'නිර්මාණකරුවෙකු B-ARG1', 'සිටින B-have.03', 'බැවිනි O', '. O']]
# 100.0
# [['ඔබ B-ARG0', 'නිවැරදි B-ARG1', 'දේ I-ARG1', 'කර B-do.02', 'ඇත I-do.02', '. O']]
# [['ඔබ B-ARG0', 'නිවැරදි B-ARG1', 'දේ I-ARG1', 'කර B-do.02', 'ඇත O', '. O'], ['ඔබ O', 'නිවැරදි O', 'දේ O', 'කර O', 'ඇත B-have.01', '. O']]
# 75.0
# [['අද B-ARGM-TMP', 'කවුරුහරි B-ARG0', 'සරණාගතයන් B-ARG1', 'ගැන I-ARG1', 'කතා B-speak.01', 'කළා I-speak.01', '. O']]
# [['අද B-ARGM-TMP', 'කවුරුහරි B-ARG0', 'සරණාගතයන් B-ARG1', 'ගැන I-ARG1', 'කතා B-speak.01', 'කළා I-speak.01', '. O']]
# 100.0
# [['යම් B-ARG1', 'ව්\u200dයාකූලතාවයක් I-ARG1', 'ඇතිවීමට I-ARG1', 'හේතුව I-ARG1', 'එය B-ARG0', 'පැහැදිලි B-explain.01', 'කරයි I-explain.01', '. O'], ['යම් B-ARG1', 'ව්\u200dයාකූලතාවයක් I-ARG1', 'ඇතිවීමට I-ARG1', 'හේතුව I-ARG1', 'එය O', 'පැහැදිලි O', 'කරයි O', '. O'], ['යම් B-ARG1', 'ව්\u200dයාකූලතාවයක් I-ARG1', 'ඇතිවීමට O', 'හේතුව B-ARGM-CAU', 'එය O', 'පැහැදිලි O', 'කරයි O', '. O']]
# [['යම් B-ARG1', 'ව්\u200dයාකූලතාවයක් I-ARG1', 'ඇතිවීමට I-ARG1', 'හේතුව I-ARG1', 'එය B-ARG0', 'පැහැදිලි B-explain.01', 'කරයි I-explain.01', '. O']]
# 100.0
# [['මෙම B-ARG1', 'තත්වය I-ARG1', 'පිරිහෙන O', 'අතර O', 'එය O', 'නැවැත්විය B-stop.01', 'යුතුය B-ARGM-MOD', '. O'], ['මෙම B-ARG1', 'තත්වය I-ARG1', 'පිරිහෙන B-ARG2', 'අතර O', 'එය O', 'නැවැත්විය O', 'යුතුය O', '. O']]
# [['මෙම B-ARG1', 'තත්වය I-ARG1', 'පිරිහෙන O', 'අතර O', 'එය O', 'නැවැත්විය B-stop.01', 'යුතුය B-ARGM-MOD', '. O']]
# 100.0
# [['කොමිසම B-ARG0', 'මෙම B-ARG1', 'විවාදය I-ARG1', 'සමීපව B-ARGM-MNR', 'අනුගමනය B-follow.02', 'කරයි I-follow.02', '. O']]
# [['කොමිසම B-ARG0', 'මෙම B-ARG1', 'විවාදය I-ARG1', 'සමීපව B-ARGM-MNR', 'අනුගමනය B-follow.02', 'කරයි I-follow.02', '. O']]
# 100.0
# [['එබැවින් O', 'මම I-ARG0', 'එයට B-ARG1', 'එරෙහිව I-ARG1', 'ඡන්දය B-vote.01', 'දීමට I-vote.01', 'තෝරාගෙන O', 'ඇත්තෙමි O', '. O'], ['එබැවින් B-ARGM-DIS', 'මම I-ARG0', 'එයට B-ARG1', 'එරෙහිව I-ARG1', 'ඡන්දය  I-ARG1', 'දීමට  I-ARG1', 'තෝරාගෙන B-choose.01', 'ඇත්තෙමි I-choose.01', '. O']]
# [['එබැවින් B-ARG0', 'මම I-ARG0', 'එයට B-ARG1', 'එරෙහිව I-ARG1', 'ඡන්දය B-vote.01', 'දීමට O', 'තෝරාගෙන O', 'ඇත්තෙමි O', '. O']]
# 33.92857142857143
# [['මෙය B-ARG1', 'හොඳ B-ARG2', 'සැකසුමක් I-ARG2', 'වන්නේ B-be.01', 'එබැවිනි B-ARGM-CAU', '. O']]
# [['මෙය B-ARG1', 'හොඳ B-ARG2', 'සැකසුමක් I-ARG2', 'වන්නේ O', 'එබැවිනි B-ARGM-CAU', '. O']]
# 0
# [['එය B-ARG1', 'අතිශය B-ARG2', 'ඵලදායී I-ARG2', 'හා I-ARG2', 'රසවත් I-ARG2', 'විවාදයක් I-ARG2', 'විය B-be.01', '. O']]
# [['එය B-ARG1', 'අතිශය B-ARG2', 'ඵලදායී I-ARG2', 'හා I-ARG2', 'රසවත් I-ARG2', 'විවාදයක් I-ARG2', 'විය B-be.01', '. O']]
# 100.0
# [['එය B-ARG1', 'අනතුරුදායක B-ARG2', 'විය B-be.01', 'හැකිය O', '. O']]
# [['එය B-ARG1', 'අනතුරුදායක B-ARG2', 'විය B-be.01', 'හැකිය I-ARG2', '. O']]
# 87.5
# [['අපි B-ARG1', 'මේ B-ARG2', 'ජීවිතයේ I-ARG2', 'විඥානවාදී I-ARG2', 'විය B-be.01', 'යුතුයි O', '. O']]
# [['අපි B-ARG1', 'මේ B-ARGM-TMP', 'ජීවිතයේ I-ARGM-TMP', 'විඥානවාදී B-ARG2', 'විය B-be.01', 'යුතුයි O', '. O']]
# 75.0
# [['මම B-ARG0', 'දන්නේ B-know.01', 'නැහැ B-ARGM-NEG', 'මොනවා B-ARG1', 'කියන්නද I-ARG1', 'කියල I-ARG1', '. O'], ['මම B-ARG0', 'දන්නේ O', 'නැහැ O', 'මොනවා B-ARG1', 'කියන්නද B-say.01', 'කියල O', '. O']]
# [['මම B-ARG0', 'දන්නේ B-know.01', 'නැහැ B-ARGM-NEG', 'මොනවා B-ARG1', 'කියන්නද I-ARG1', 'කියල I-ARG1', '. O'], ['මම B-ARG0', 'දන්නේ O', 'නැහැ O', 'මොනවා B-ARG1', 'කියන්නද B-say.01', 'කියල O', '. O']]
# 100.0
# [['ඉදිරි B-come.01', 'පරම්පරාවන් B-ARG1', 'සඳහා O', 'අපගේ O', 'යුතුකම O', 'මෙයයි O', '. O'], ['ඉදිරි B-ARG2', 'පරම්පරාවන් I-ARG2', 'සඳහා I-ARG2', 'අපගේ I-ARG2', 'යුතුකම I-ARG2', 'මෙයයි B-ARG1', '. O']]
# [['ඉදිරි B-come.01', 'පරම්පරාවන් O', 'සඳහා O', 'අපගේ O', 'යුතුකම O', 'මෙයයි O', '. O']]
# 91.66666666666666

# %%
print("Total no. of fully correct sentences = ", noOfFullyCorrectSentences, "out of", noOfSentences, "=", (noOfFullyCorrectSentences*100)/noOfSentences, "%")
# Out:
# Total no. of fully correct sentences =  798 out of 1732 = 46.07390300230947 %

# %%
print("Total no. of sentences with correctly predicted predicates with the senses (SRL not considered) = ", noOfSentencesWithCorrectPredsWithSensesNotConsideringSRL, "out of", noOfSentences, "=", (noOfSentencesWithCorrectPredsWithSensesNotConsideringSRL*100)/noOfSentences, "%")
# Out:
# Total no. of sentences with correctly predicted predicates with the senses (SRL not considered) =  1490 out of 1732 = 86.02771362586606 %

# %%
print("Total no. of sentences with correctly predicted predicate-verbs (SRL and senses are not considered) = ", noOfSentencesWithCorrectPredsNotConsideringSRLAndSenses, "out of", noOfSentences, "=", (noOfSentencesWithCorrectPredsNotConsideringSRLAndSenses*100)/noOfSentences, "%")
# Out:
# Total no. of sentences with correctly predicted predicate-verbs (SRL and senses are not considered) =  1492 out of 1732 = 86.14318706697459 %

# %%
print("Overall accuracy = ", overallAccuarcy, "out of", noOfSentences, "=", (overallAccuarcy*100)/noOfSentences, "%")
# Out:
# Overall accuracy =  1464.710091991342 out of 1732 = 84.56755727432692 %

# %%
print("No. of 0-30% - partially correct sentences = ", sentCat4, "out of", noOfSentences, "=", (sentCat4*100)/noOfSentences, "%")
print("No. of 30-60% - partially correct sentences = ", sentCat3, "out of", noOfSentences, "=", (sentCat3*100)/noOfSentences, "%")
print("No. of 60-80% - partially correct sentences = ", sentCat2, "out of", noOfSentences, "=", (sentCat2*100)/noOfSentences, "%")
print("No. of 80-100% - partially correct sentences = ", sentCat1, "out of", noOfSentences, "=", (sentCat1*100)/noOfSentences, "%")
# Out:
# No. of 0-30% - partially correct sentences =  112 out of 1732 = 6.466512702078522 %
# No. of 30-60% - partially correct sentences =  121 out of 1732 = 6.986143187066975 %
# No. of 60-80% - partially correct sentences =  167 out of 1732 = 9.64203233256351 %
# No. of 80-100% - partially correct sentences =  1332 out of 1732 = 76.905311778291 %

# %%
# Total no. of fully correct sentences =  798 out of 1732 = 46.07390300230947 %
# Total no. of sentences with correctly predicted predicates with the senses (SRL not considered) =  1490 out of 1732 = 86.02771362586606 %
# Total no. of sentences with correctly predicted predicate-verbs (SRL and senses are not considered) =  1492 out of 1732 = 86.14318706697459 %
# Overall accuracy =  1464.710091991342 out of 1732 = 84.56755727432692 %
# No. of 0-30% - partially correct sentences =  112 out of 1732 = 6.466512702078522 %
# No. of 30-60% - partially correct sentences =  121 out of 1732 = 6.986143187066975 %
# No. of 60-80% - partially correct sentences =  167 out of 1732 = 9.64203233256351 %
# No. of 80-100% - partially correct sentences =  1332 out of 1732 = 76.905311778291 %
